# %%
# SauceDemo Automation with Playwright
# !pip install pytest-playwright allure-pytest pytest-html -q
# !playwright install chromium
# !playwright install-deps

# Install Allure command line
# !wget -q https://github.com/allure-framework/allure2/releases/download/2.24.1/allure-2.24.1.tgz
# !tar -xzf allure-2.24.1.tgz
# !rm allure-2.24.1.tgz
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 MB 19.6 MB/s eta 0:00:00
# Downloading Chromium 143.0.7499.4 (playwright build v1200) from https://cdn.playwright.dev/dbazure/download/playwright/builds/chromium/1200/chromium-linux.zip
# (node:623) [DEP0169] DeprecationWarning: `url.parse()` behavior is not standardized and prone to errors that have security implications. Use the WHATWG URL API instead. CVEs are not issued for `url.parse()` vulnerabilities.
# (Use `node --trace-deprecation ...` to show where the warning was created)
# 164.7 MiB [] 0% 0.0s164.7 MiB [] 0% 110.8s164.7 MiB [] 0% 376.3s164.7 MiB [] 0% 423.9s164.7 MiB [] 0% 340.3s164.7 MiB [] 0% 293.8s164.7 MiB [] 0% 264.3s164.7 MiB [] 0% 244.6s164.7 MiB [] 0% 228.8s164.7 MiB [] 0% 214.2s164.7 MiB [] 0% 201.1s164.7 MiB [] 0% 189.9s164.7 MiB [] 0% 166.6s164.7 MiB [] 0% 150.1s164.7 MiB [] 0% 137.6s164.7 MiB [] 0% 127.5s164.7 MiB [] 0% 119.1s164.7 MiB [] 0% 110.0s164.7 MiB [] 0% 100.5s164.7 MiB [] 0% 91.3s164.7 MiB [] 0% 82.3s164.7 MiB [] 0% 74.8s164.7 MiB [] 0% 68.1s164.7 MiB [] 0% 62.2s164.7 MiB [] 1% 56.8s164.7 MiB [] 1% 51.7s164.7 MiB [] 1% 46.8s164.7 MiB [] 1% 42.2s164.7 MiB [] 1% 37.9s164.7 MiB [] 1% 34.2s164.7 MiB [] 2% 31.0s164.7 MiB [] 2% 27.8s164.7 MiB [] 2% 24.9s164.7 MiB [] 3% 22.6s164.7 MiB [] 3% 20.2s164.7 MiB [] 3% 19.4s164.7 MiB [] 4% 17.8s164.7 MiB [] 4% 16.2s164.7 MiB [] 5% 14.5s164.7 MiB [] 5% 13.5s164.7 MiB [] 6% 12.6s164.7 MiB [] 6% 12.7s164.7 MiB [] 7% 11.3s164.7 MiB [] 7% 10.8s164.7 MiB [] 8% 10.3s164.7 MiB [] 8% 9.8s164.7 MiB [] 9% 9.5s164.7 MiB [] 9% 9.2s164.7 MiB [] 10% 9.0s164.7 MiB [] 10% 8.6s164.7 MiB [] 11% 8.3s164.7 MiB [] 12% 7.9s164.7 MiB [] 12% 7.7s164.7 MiB [] 13% 7.4s164.7 MiB [] 13% 7.2s164.7 MiB [] 14% 7.1s164.7 MiB [] 14% 7.0s164.7 MiB [] 15% 6.7s164.7 MiB [] 15% 6.5s164.7 MiB [] 16% 6.4s164.7 MiB [] 16% 6.3s164.7 MiB [] 17% 6.1s164.7 MiB [] 17% 6.0s164.7 MiB [] 18% 5.9s164.7 MiB [] 18% 5.8s164.7 MiB [] 19% 5.7s164.7 MiB [] 20% 5.5s164.7 MiB [] 20% 5.4s164.7 MiB [] 21% 5.3s164.7 MiB [] 21% 5.2s164.7 MiB [] 22% 5.1s164.7 MiB [] 23% 5.0s164.7 MiB [] 23% 4.9s164.7 MiB [] 24% 4.9s164.7 MiB [] 24% 4.8s164.7 MiB [] 25% 4.7s164.7 MiB [] 25% 4.6s164.7 MiB [] 26% 4.6s164.7 MiB [] 26% 4.5s164.7 MiB [] 27% 4.4s164.7 MiB [] 28% 4.3s164.7 MiB [] 28% 4.2s164.7 MiB [] 29% 4.2s164.7 MiB [] 30% 4.1s164.7 MiB [] 31% 4.0s164.7 MiB [] 32% 3.9s164.7 MiB [] 33% 3.8s164.7 MiB [] 34% 3.7s164.7 MiB [] 35% 3.6s164.7 MiB [] 36% 3.5s164.7 MiB [] 37% 3.4s164.7 MiB [] 38% 3.4s164.7 MiB [] 38% 3.3s164.7 MiB [] 39% 3.3s164.7 MiB [] 39% 3.2s164.7 MiB [] 40% 3.2s164.7 MiB [] 41% 3.1s164.7 MiB [] 42% 3.1s164.7 MiB [] 42% 3.0s164.7 MiB [] 43% 3.0s164.7 MiB [] 43% 2.9s164.7 MiB [] 44% 2.9s164.7 MiB [] 45% 2.9s164.7 MiB [] 45% 2.8s164.7 MiB [] 46% 2.8s164.7 MiB [] 47% 2.7s164.7 MiB [] 48% 2.7s164.7 MiB [] 48% 2.6s164.7 MiB [] 49% 2.6s164.7 MiB [] 50% 2.5s164.7 MiB [] 51% 2.5s164.7 MiB [] 51% 2.4s164.7 MiB [] 52% 2.4s164.7 MiB [] 53% 2.3s164.7 MiB [] 54% 2.3s164.7 MiB [] 55% 2.2s164.7 MiB [] 56% 2.2s164.7 MiB [] 56% 2.1s164.7 MiB [] 57% 2.1s164.7 MiB [] 58% 2.0s164.7 MiB [] 59% 2.0s164.7 MiB [] 60% 1.9s164.7 MiB [] 61% 1.9s164.7 MiB [] 62% 1.8s164.7 MiB [] 63% 1.8s164.7 MiB [] 63% 1.7s164.7 MiB [] 64% 1.7s164.7 MiB [] 65% 1.7s164.7 MiB [] 65% 1.6s164.7 MiB [] 66% 1.6s164.7 MiB [] 67% 1.6s164.7 MiB [] 67% 1.5s164.7 MiB [] 68% 1.5s164.7 MiB [] 69% 1.5s164.7 MiB [] 69% 1.4s164.7 MiB [] 70% 1.4s164.7 MiB [] 71% 1.4s164.7 MiB [] 71% 1.3s164.7 MiB [] 72% 1.3s164.7 MiB [] 73% 1.2s164.7 MiB [] 74% 1.2s164.7 MiB [] 75% 1.1s164.7 MiB [] 76% 1.1s164.7 MiB [] 77% 1.1s164.7 MiB [] 77% 1.0s164.7 MiB [] 78% 1.0s164.7 MiB [] 79% 1.0s164.7 MiB [] 79% 0.9s164.7 MiB [] 80% 0.9s164.7 MiB [] 81% 0.8s164.7 MiB [] 82% 0.8s164.7 MiB [] 83% 0.8s164.7 MiB [] 83% 0.7s164.7 MiB [] 84% 0.7s164.7 MiB [] 85% 0.7s164.7 MiB [] 86% 0.6s164.7 MiB [] 87% 0.6s164.7 MiB [] 88% 0.5s164.7 MiB [] 89% 0.5s164.7 MiB [] 90% 0.4s164.7 MiB [] 91% 0.4s164.7 MiB [] 92% 0.4s164.7 MiB [] 92% 0.3s164.7 MiB [] 93% 0.3s164.7 MiB [] 94% 0.3s164.7 MiB [] 94% 0.2s164.7 MiB [] 95% 0.2s164.7 MiB [] 96% 0.2s164.7 MiB [] 97% 0.1s164.7 MiB [] 98% 0.1s164.7 MiB [] 99% 0.0s164.7 MiB [] 100% 0.0s
# Chromium 143.0.7499.4 (playwright build v1200) downloaded to /root/.cache/ms-playwright/chromium-1200
# Downloading FFMPEG playwright build v1011 from https://cdn.playwright.dev/dbazure/download/playwright/builds/ffmpeg/1011/ffmpeg-linux.zip
# (node:670) [DEP0169] DeprecationWarning: `url.parse()` behavior is not standardized and prone to errors that have security implications. Use the WHATWG URL API instead. CVEs are not issued for `url.parse()` vulnerabilities.
# (Use `node --trace-deprecation ...` to show where the warning was created)
# 2.3 MiB [] 0% 0.0s2.3 MiB [] 14% 0.1s2.3 MiB [] 59% 0.0s2.3 MiB [] 100% 0.0s
# FFMPEG playwright build v1011 downloaded to /root/.cache/ms-playwright/ffmpeg-1011
# Downloading Chromium Headless Shell 143.0.7499.4 (playwright build v1200) from https://cdn.playwright.dev/dbazure/download/playwright/builds/chromium/1200/chromium-headless-shell-linux.zip
# (node:685) [DEP0169] DeprecationWarning: `url.parse()` behavior is not standardized and prone to errors that have security implications. Use the WHATWG URL API instead. CVEs are not issued for `url.parse()` vulnerabilities.
# (Use `node --trace-deprecation ...` to show where the warning was created)
# 109.7 MiB [] 0% 0.0s109.7 MiB [] 0% 73.8s109.7 MiB [] 0% 252.9s109.7 MiB [] 0% 286.4s109.7 MiB [] 0% 229.5s109.7 MiB [] 0% 197.9s109.7 MiB [] 0% 177.8s109.7 MiB [] 0% 163.9s109.7 MiB [] 0% 153.2s109.7 MiB [] 0% 143.8s109.7 MiB [] 0% 134.9s109.7 MiB [] 0% 127.3s109.7 MiB [] 0% 111.6s109.7 MiB [] 0% 100.5s109.7 MiB [] 0% 91.9s109.7 MiB [] 0% 87.1s109.7 MiB [] 0% 80.2s109.7 MiB [] 0% 73.8s109.7 MiB [] 0% 67.4s109.7 MiB [] 0% 62.1s109.7 MiB [] 0% 55.2s109.7 MiB [] 1% 50.1s109.7 MiB [] 1% 46.0s109.7 MiB [] 1% 42.4s109.7 MiB [] 1% 38.6s109.7 MiB [] 1% 35.3s109.7 MiB [] 1% 31.9s109.7 MiB [] 2% 28.6s109.7 MiB [] 2% 25.8s109.7 MiB [] 2% 23.2s109.7 MiB [] 3% 21.0s109.7 MiB [] 3% 20.2s109.7 MiB [] 3% 20.3s109.7 MiB [] 3% 19.0s109.7 MiB [] 4% 15.1s109.7 MiB [] 5% 13.2s109.7 MiB [] 6% 11.3s109.7 MiB [] 6% 10.8s109.7 MiB [] 7% 11.0s109.7 MiB [] 7% 10.6s109.7 MiB [] 8% 9.7s109.7 MiB [] 9% 8.8s109.7 MiB [] 10% 8.1s109.7 MiB [] 10% 7.8s109.7 MiB [] 11% 7.1s109.7 MiB [] 12% 6.8s109.7 MiB [] 13% 6.3s109.7 MiB [] 14% 6.3s109.7 MiB [] 15% 5.9s109.7 MiB [] 15% 5.6s109.7 MiB [] 16% 5.5s109.7 MiB [] 17% 5.3s109.7 MiB [] 18% 5.0s109.7 MiB [] 19% 4.8s109.7 MiB [] 20% 4.6s109.7 MiB [] 20% 4.5s109.7 MiB [] 21% 4.4s109.7 MiB [] 22% 4.3s109.7 MiB [] 23% 4.1s109.7 MiB [] 24% 4.1s109.7 MiB [] 25% 3.9s109.7 MiB [] 25% 3.8s109.7 MiB [] 26% 3.7s109.7 MiB [] 27% 3.6s109.7 MiB [] 28% 3.5s109.7 MiB [] 29% 3.4s109.7 MiB [] 30% 3.3s109.7 MiB [] 31% 3.2s109.7 MiB [] 32% 3.1s109.7 MiB [] 33% 3.0s109.7 MiB [] 34% 3.0s109.7 MiB [] 35% 2.9s109.7 MiB [] 35% 2.8s109.7 MiB [] 36% 2.7s109.7 MiB [] 37% 2.7s109.7 MiB [] 38% 2.7s109.7 MiB [] 39% 2.6s109.7 MiB [] 40% 2.5s109.7 MiB [] 41% 2.4s109.7 MiB [] 42% 2.4s109.7 MiB [] 43% 2.3s109.7 MiB [] 45% 2.2s109.7 MiB [] 46% 2.1s109.7 MiB [] 47% 2.1s109.7 MiB [] 48% 2.0s109.7 MiB [] 49% 2.0s109.7 MiB [] 50% 1.9s109.7 MiB [] 51% 1.9s109.7 MiB [] 52% 1.8s109.7 MiB [] 53% 1.8s109.7 MiB [] 55% 1.7s109.7 MiB [] 56% 1.6s109.7 MiB [] 57% 1.6s109.7 MiB [] 58% 1.5s109.7 MiB [] 59% 1.5s109.7 MiB [] 60% 1.5s109.7 MiB [] 61% 1.4s109.7 MiB [] 62% 1.4s109.7 MiB [] 63% 1.3s109.7 MiB [] 65% 1.3s109.7 MiB [] 65% 1.2s109.7 MiB [] 66% 1.2s109.7 MiB [] 67% 1.2s109.7 MiB [] 68% 1.1s109.7 MiB [] 69% 1.1s109.7 MiB [] 70% 1.1s109.7 MiB [] 70% 1.0s109.7 MiB [] 71% 1.0s109.7 MiB [] 72% 1.0s109.7 MiB [] 73% 0.9s109.7 MiB [] 75% 0.9s109.7 MiB [] 75% 0.8s109.7 MiB [] 76% 0.8s109.7 MiB [] 77% 0.8s109.7 MiB [] 78% 0.7s109.7 MiB [] 79% 0.7s109.7 MiB [] 80% 0.7s109.7 MiB [] 81% 0.6s109.7 MiB [] 82% 0.6s109.7 MiB [] 83% 0.6s109.7 MiB [] 83% 0.5s109.7 MiB [] 85% 0.5s109.7 MiB [] 86% 0.4s109.7 MiB [] 87% 0.4s109.7 MiB [] 88% 0.4s109.7 MiB [] 89% 0.4s109.7 MiB [] 90% 0.3s109.7 MiB [] 91% 0.3s109.7 MiB [] 92% 0.3s109.7 MiB [] 93% 0.2s109.7 MiB [] 95% 0.2s109.7 MiB [] 95% 0.1s109.7 MiB [] 96% 0.1s109.7 MiB [] 97% 0.1s109.7 MiB [] 98% 0.1s109.7 MiB [] 99% 0.0s109.7 MiB [] 100% 0.0s
# Chromium Headless Shell 143.0.7499.4 (playwright build v1200) downloaded to /root/.cache/ms-playwright/chromium_headless_shell-1200
# Installing dependencies...
# Hit:1 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:2 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:3 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:5 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:6 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:8 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6,205 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [69.2 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,968 kB]
# Get:13 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,289 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,637 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [6,411 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,600 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [83.9 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [37.2 kB]
# Get:19 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,864 kB]
# Get:20 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,592 kB]
# Fetched 36.2 MB in 4s (10.3 MB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-liberation is already the newest version (1:1.07.4-11).
# libasound2 is already the newest version (1.2.6.1-1ubuntu1).
# libasound2 set to manually installed.
# libcairo-gobject2 is already the newest version (1.16.0-5ubuntu2).
# libcairo-gobject2 set to manually installed.
# libcairo2 is already the newest version (1.16.0-5ubuntu2).
# libcairo2 set to manually installed.
# libegl1 is already the newest version (1.4.0-1).
# libepoxy0 is already the newest version (1.5.10-1).
# libepoxy0 set to manually installed.
# libevent-2.1-7 is already the newest version (2.1.12-stable-1build3).
# libevent-2.1-7 set to manually installed.
# libfontconfig1 is already the newest version (2.13.1-4.2ubuntu5).
# libgles2 is already the newest version (1.4.0-1).
# libglx0 is already the newest version (1.4.0-1).
# libglx0 set to manually installed.
# libicu70 is already the newest version (70.1-2).
# libicu70 set to manually installed.
# libjpeg-turbo8 is already the newest version (2.1.2-0ubuntu1).
# libjpeg-turbo8 set to manually installed.
# liblcms2-2 is already the newest version (2.12~rc1-2build2).
# liblcms2-2 set to manually installed.
# libopengl0 is already the newest version (1.4.0-1).
# libopus0 is already the newest version (1.3.1-0.1build2).
# libopus0 set to manually installed.
# libxcb-shm0 is already the newest version (1.14-3ubuntu3).
# libxcb-shm0 set to manually installed.
# libxcb1 is already the newest version (1.14-3ubuntu3).
# libxcb1 set to manually installed.
# libxcursor1 is already the newest version (1:1.2.0-2build4).
# libxcursor1 set to manually installed.
# libxdamage1 is already the newest version (1:1.1.5-2build2).
# libxdamage1 set to manually installed.
# libxext6 is already the newest version (2:1.3.4-1build1).
# libxfixes3 is already the newest version (1:6.0.0-1).
# libxfixes3 set to manually installed.
# libxi6 is already the newest version (2:1.8-1build1).
# libxi6 set to manually installed.
# libxkbcommon0 is already the newest version (1.4.0-1).
# libxkbcommon0 set to manually installed.
# libxrandr2 is already the newest version (2:1.5.2-1build1).
# libxrandr2 set to manually installed.
# libxrender1 is already the newest version (1:0.9.10-1build4).
# libx264-163 is already the newest version (2:0.163.3060+git5db6aa6-2build1).
# libx264-163 set to manually installed.
# libatomic1 is already the newest version (12.3.0-1ubuntu1~22.04.2).
# libatomic1 set to manually installed.
# libcups2 is already the newest version (2.4.1op1-1ubuntu4.16).
# libcups2 set to manually installed.
# libdbus-1-3 is already the newest version (1.12.20-2ubuntu4.1).
# libdbus-1-3 set to manually installed.
# libdrm2 is already the newest version (2.4.113-2~ubuntu0.22.04.1).
# libdrm2 set to manually installed.
# libfreetype6 is already the newest version (2.11.1+dfsg-1ubuntu0.3).
# libfreetype6 set to manually installed.
# libgbm1 is already the newest version (23.2.1-1ubuntu3.1~22.04.3).
# libgbm1 set to manually installed.
# libgdk-pixbuf-2.0-0 is already the newest version (2.42.8+dfsg-1ubuntu0.4).
# libgdk-pixbuf-2.0-0 set to manually installed.
# libgstreamer1.0-0 is already the newest version (1.20.3-0ubuntu1.1).
# libgstreamer1.0-0 set to manually installed.
# libgtk-4-1 is already the newest version (4.6.9+ds-0ubuntu0.22.04.2).
# libgtk-4-1 set to manually installed.
# libharfbuzz0b is already the newest version (2.7.4-1ubuntu3.2).
# libharfbuzz0b set to manually installed.
# libnspr4 is already the newest version (2:4.35-0ubuntu0.22.04.1).
# libnspr4 set to manually installed.
# libnss3 is already the newest version (2:3.98-0ubuntu0.22.04.2).
# libnss3 set to manually installed.
# libopenjp2-7 is already the newest version (2.4.0-6ubuntu0.4).
# libopenjp2-7 set to manually installed.
# libpango-1.0-0 is already the newest version (1.50.6+ds-2ubuntu1).
# libpango-1.0-0 set to manually installed.
# libpangocairo-1.0-0 is already the newest version (1.50.6+ds-2ubuntu1).
# libpangocairo-1.0-0 set to manually installed.
# libpng16-16 is already the newest version (1.6.37-3ubuntu0.1).
# libpng16-16 set to manually installed.
# libwayland-client0 is already the newest version (1.20.0-1ubuntu0.1).
# libwayland-client0 set to manually installed.
# libwayland-egl1 is already the newest version (1.20.0-1ubuntu0.1).
# libwayland-egl1 set to manually installed.
# libwayland-server0 is already the newest version (1.20.0-1ubuntu0.1).
# libwayland-server0 set to manually installed.
# libwebpdemux2 is already the newest version (1.2.2-2ubuntu0.22.04.2).
# libx11-6 is already the newest version (2:1.7.5-1ubuntu0.3).
# libx11-6 set to manually installed.
# libx11-xcb1 is already the newest version (2:1.7.5-1ubuntu0.3).
# libx11-xcb1 set to manually installed.
# libxml2 is already the newest version (2.9.13+dfsg-1ubuntu0.10).
# libxml2 set to manually installed.
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.16).
# The following additional packages will be installed:
#   dictionaries-common glib-networking glib-networking-common
#   glib-networking-services gsettings-desktop-schemas hunspell-en-us libaa1
#   libabsl20210324 libaspell15 libatk1.0-data libcdparanoia0 libdca0 libdv4
#   libdvdnav4 libdvdread8 libfaad2 libfluidsynth3 libfreeaptx0 libgav1-0
#   libglib2.0-bin libglib2.0-dev libglib2.0-dev-bin libgssdp-1.2-0
#   libgstreamer-plugins-bad1.0-0 libgstreamer-plugins-good1.0-0 libgtk-3-common
#   libgupnp-1.2-1 libgupnp-igd-1.0-4 libhunspell-1.7-0 libilmbase25
#   libinstpatch-1.0-2 libjson-glib-1.0-0 libjson-glib-1.0-common libkate1
#   libldacbt-enc2 libltc11 libmjpegutils-2.1-0 libmodplug1 libmpcdec6
#   libmpeg2encpp-2.1-0 libmplex2-2.1-0 libnice10 libopenexr25 libopenh264-6
#   libopenni2-0 liborc-0.4-0 libqrencode4 libsbc1 libsecret-common libshout3
#   libsoundtouch1 libsoup-3.0-common libsoup2.4-1 libsoup2.4-common libspandsp2
#   libsrtp2-1 libtag1v5 libtag1v5-vanilla libtext-iconv-perl libv4l-0
#   libv4lconvert0 libvisual-0.4-0 libvo-aacenc0 libvo-amrwbenc0 libwavpack1
#   libwebrtc-audio-processing1 libwildmidi2 libyuv0 libzbar0 libzxingcore1
#   session-migration timgm6mb-soundfont xfonts-encodings xfonts-utils
# Suggested packages:
#   ispell | aspell | hunspell wordlist frei0r-plugins gvfs hunspell
#   openoffice.org-hunspell | openoffice.org-core aspell libdv-bin oss-compat
#   libdvdcss2 libenchant-2-voikko libglib2.0-doc libgdk-pixbuf2.0-bin
#   | libgdk-pixbuf2.0-dev libxml2-utils libvisual-0.4-plugins gnome-shell
#   | notification-daemon libwildmidi-config fluid-soundfont-gm
# Recommended packages:
#   fonts-ipafont-mincho fonts-tlwg-loma gstreamer1.0-x aspell-en
#   | aspell-dictionary | aspell6a-dictionary at-spi2-core enchant-2
#   xdg-user-dirs gstreamer1.0-gl libgtk-3-bin librsvg2-common
#   libmagickcore-6.q16-6-extra
# The following NEW packages will be installed:
#   dictionaries-common fonts-freefont-ttf fonts-ipafont-gothic
#   fonts-noto-color-emoji fonts-tlwg-loma-otf fonts-unifont fonts-wqy-zenhei
#   glib-networking glib-networking-common glib-networking-services
#   gsettings-desktop-schemas gstreamer1.0-libav gstreamer1.0-plugins-bad
#   gstreamer1.0-plugins-base gstreamer1.0-plugins-good hunspell-en-us libaa1
#   libabsl20210324 libaspell15 libatk-bridge2.0-0 libatk1.0-0 libatk1.0-data
#   libatspi2.0-0 libavif13 libcdparanoia0 libdbus-glib-1-2 libdca0 libdv4
#   libdvdnav4 libdvdread8 libenchant-2-2 libevdev2 libfaad2 libffi7
#   libfluidsynth3 libfreeaptx0 libgav1-0 libgssdp-1.2-0 libgstreamer-gl1.0-0
#   libgstreamer-plugins-bad1.0-0 libgstreamer-plugins-base1.0-0
#   libgstreamer-plugins-good1.0-0 libgtk-3-0 libgtk-3-common libgudev-1.0-0
#   libgupnp-1.2-1 libgupnp-igd-1.0-4 libharfbuzz-icu0 libhunspell-1.7-0
#   libhyphen0 libilmbase25 libinstpatch-1.0-2 libjson-glib-1.0-0
#   libjson-glib-1.0-common libkate1 libldacbt-enc2 libltc11 libmanette-0.2-0
#   libmjpegutils-2.1-0 libmodplug1 libmpcdec6 libmpeg2encpp-2.1-0
#   libmplex2-2.1-0 libnice10 libnotify4 libopenexr25 libopenh264-6 libopenni2-0
#   liborc-0.4-0 libproxy1v5 libqrencode4 libsbc1 libsecret-1-0 libsecret-common
#   libshout3 libsoundtouch1 libsoup-3.0-0 libsoup-3.0-common libsoup2.4-1
#   libsoup2.4-common libspandsp2 libsrtp2-1 libtag1v5 libtag1v5-vanilla
#   libtext-iconv-perl libv4l-0 libv4lconvert0 libvisual-0.4-0 libvo-aacenc0
#   libvo-amrwbenc0 libwavpack1 libwebrtc-audio-processing1 libwildmidi2
#   libwoff1 libxcomposite1 libxtst6 libyuv0 libzbar0 libzxingcore1
#   session-migration timgm6mb-soundfont xfonts-cyrillic xfonts-encodings
#   xfonts-scalable xfonts-utils
# The following packages will be upgraded:
#   libglib2.0-0 libglib2.0-bin libglib2.0-dev libglib2.0-dev-bin libxslt1.1
# 5 upgraded, 105 newly installed, 0 to remove and 28 not upgraded.
# Need to get 57.3 MB of archives.
# After this operation, 142 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-ipafont-gothic all 00303-21ubuntu1 [3,513 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libglib2.0-dev amd64 2.72.4-0ubuntu2.7 [1,742 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libglib2.0-dev-bin amd64 2.72.4-0ubuntu2.7 [117 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libglib2.0-bin amd64 2.72.4-0ubuntu2.7 [80.9 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libglib2.0-0 amd64 2.72.4-0ubuntu2.7 [1,467 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtext-iconv-perl amd64 1.7-7build3 [14.3 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 dictionaries-common all 1.28.14 [185 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-freefont-ttf all 20120503-10build1 [2,388 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 fonts-noto-color-emoji all 2.047-0ubuntu0.22.04.1 [10.0 MB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-tlwg-loma-otf all 1:0.7.3-1 [107 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-unifont all 1:14.0.01-1 [3,551 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-wqy-zenhei all 0.9.45-8 [7,472 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 libproxy1v5 amd64 0.4.17-2 [51.9 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 glib-networking-common all 2.72.0-1 [3,718 B]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 glib-networking-services amd64 2.72.0-1 [9,982 B]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 session-migration amd64 0.3.6 [9,774 B]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 gsettings-desktop-schemas all 42.0-1ubuntu1 [31.1 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 glib-networking amd64 2.72.0-1 [69.8 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 liborc-0.4-0 amd64 1:0.4.32-2ubuntu0.1 [228 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgstreamer-plugins-base1.0-0 amd64 1.20.1-1ubuntu0.5 [848 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 gstreamer1.0-libav amd64 1.20.3-0ubuntu1 [103 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcdparanoia0 amd64 3.10.2+debian-14build2 [49.3 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvisual-0.4-0 amd64 0.4.0-17build2 [108 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gstreamer1.0-plugins-base amd64 1.20.1-1ubuntu0.5 [712 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/main amd64 libaa1 amd64 1.4p5-50build1 [51.9 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdv4 amd64 1.0.0-14build1 [61.9 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgstreamer-plugins-good1.0-0 amd64 1.20.3-0ubuntu1.4 [30.2 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgudev-1.0-0 amd64 1:237-2build1 [16.3 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/main amd64 libshout3 amd64 2.4.5-1build3 [54.5 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtag1v5-vanilla amd64 1.11.1+dfsg.1-3ubuntu3 [304 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtag1v5 amd64 1.11.1+dfsg.1-3ubuntu3 [11.5 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/main amd64 libv4lconvert0 amd64 1.22.1-2build1 [82.4 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/main amd64 libv4l-0 amd64 1.22.1-2build1 [44.9 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwavpack1 amd64 5.4.0-1build2 [83.7 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libsoup2.4-common all 2.74.2-3ubuntu0.6 [4,778 B]
# Get:36 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libsoup2.4-1 amd64 2.74.2-3ubuntu0.6 [288 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gstreamer1.0-plugins-good amd64 1.20.3-0ubuntu1.4 [2,009 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/main amd64 hunspell-en-us all 1:2020.12.07-2 [280 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libabsl20210324 amd64 0~20210324.2-2ubuntu0.2 [386 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/main amd64 libaspell15 amd64 0.60.8-4build1 [325 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-data all 2.36.0-3build1 [2,824 B]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-0 amd64 2.36.0-3build1 [51.9 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatspi2.0-0 amd64 2.44.0-3 [80.9 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-bridge2.0-0 amd64 2.38.0-3 [66.6 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgav1-0 amd64 0.17.0-1build1 [336 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libyuv0 amd64 0.0~git20220104.b91df1a-2 [154 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libavif13 amd64 0.9.3-3 [69.5 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdbus-glib-1-2 amd64 0.112-2build1 [65.4 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdvdread8 amd64 6.1.2-1 [55.7 kB]
# Get:50 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdvdnav4 amd64 6.1.1-1 [39.3 kB]
# Get:51 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhunspell-1.7-0 amd64 1.7.0-4build1 [175 kB]
# Get:52 http://archive.ubuntu.com/ubuntu jammy/main amd64 libenchant-2-2 amd64 2.3.2-1ubuntu2 [50.9 kB]
# Get:53 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libfaad2 amd64 2.10.0-2 [197 kB]
# Get:54 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libffi7 amd64 3.3-5ubuntu1 [19.9 kB]
# Get:55 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libinstpatch-1.0-2 amd64 1.1.6-1 [240 kB]
# Get:56 http://archive.ubuntu.com/ubuntu jammy/universe amd64 timgm6mb-soundfont all 1.3-5 [5,427 kB]
# Get:57 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libfluidsynth3 amd64 2.2.5-1 [246 kB]
# Get:58 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libfreeaptx0 amd64 0.1.1-1 [12.9 kB]
# Get:59 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgssdp-1.2-0 amd64 1.4.0.1-2build1 [48.9 kB]
# Get:60 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgstreamer-gl1.0-0 amd64 1.20.1-1ubuntu0.5 [204 kB]
# Get:61 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcomposite1 amd64 1:0.4.5-1build2 [7,192 B]
# Get:62 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk-3-common all 3.24.33-1ubuntu2.2 [239 kB]
# Get:63 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk-3-0 amd64 3.24.33-1ubuntu2.2 [3,053 kB]
# Get:64 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgupnp-1.2-1 amd64 1.4.3-1 [93.3 kB]
# Get:65 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgupnp-igd-1.0-4 amd64 1.2.0-1build1 [16.8 kB]
# Get:66 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libharfbuzz-icu0 amd64 2.7.4-1ubuntu3.2 [5,890 B]
# Get:67 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhyphen0 amd64 2.8.8-7build2 [28.2 kB]
# Get:68 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libilmbase25 amd64 2.5.7-2 [175 kB]
# Get:69 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjson-glib-1.0-common all 1.6.6-1build1 [4,432 B]
# Get:70 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjson-glib-1.0-0 amd64 1.6.6-1build1 [69.9 kB]
# Get:71 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libkate1 amd64 0.4.1-11build1 [39.4 kB]
# Get:72 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libldacbt-enc2 amd64 2.0.2.3+git20200429+ed310a0-4 [24.6 kB]
# Get:73 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libltc11 amd64 1.3.1-1 [12.3 kB]
# Get:74 http://archive.ubuntu.com/ubuntu jammy/main amd64 libevdev2 amd64 1.12.1+dfsg-1 [39.5 kB]
# Get:75 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmanette-0.2-0 amd64 0.2.6-3build1 [30.4 kB]
# Get:76 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmjpegutils-2.1-0 amd64 1:2.1.0+debian-6build1 [24.1 kB]
# Get:77 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmodplug1 amd64 1:0.8.9.0-3 [153 kB]
# Get:78 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmpcdec6 amd64 2:0.1~r495-2 [32.4 kB]
# Get:79 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmpeg2encpp-2.1-0 amd64 1:2.1.0+debian-6build1 [69.4 kB]
# Get:80 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmplex2-2.1-0 amd64 1:2.1.0+debian-6build1 [44.4 kB]
# Get:81 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libnice10 amd64 0.1.18-2 [156 kB]
# Get:82 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libnotify4 amd64 0.7.9-3ubuntu5.22.04.1 [20.3 kB]
# Get:83 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenexr25 amd64 2.5.7-1 [780 kB]
# Get:84 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenh264-6 amd64 2.2.0+dfsg-2 [407 kB]
# Get:85 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenni2-0 amd64 2.2.0.33+dfsg-15 [389 kB]
# Get:86 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqrencode4 amd64 4.1.1-1 [24.0 kB]
# Get:87 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsecret-common all 0.20.5-2 [4,278 B]
# Get:88 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsecret-1-0 amd64 0.20.5-2 [124 kB]
# Get:89 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsoundtouch1 amd64 2.3.1+ds1-1 [38.3 kB]
# Get:90 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libsoup-3.0-common all 3.0.7-0ubuntu1 [62.1 kB]
# Get:91 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libsoup-3.0-0 amd64 3.0.7-0ubuntu1 [278 kB]
# Get:92 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libspandsp2 amd64 0.0.6+dfsg-2 [272 kB]
# Get:93 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsrtp2-1 amd64 2.4.2-2 [40.7 kB]
# Get:94 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwebrtc-audio-processing1 amd64 0.3.1-0ubuntu5 [291 kB]
# Get:95 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libwildmidi2 amd64 0.4.3-1 [59.9 kB]
# Get:96 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwoff1 amd64 1.0.2-1build4 [45.2 kB]
# Get:97 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libxslt1.1 amd64 1.1.34-4ubuntu0.22.04.5 [165 kB]
# Get:98 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:99 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libzbar0 amd64 0.23.92-4build2 [121 kB]
# Get:100 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libzxingcore1 amd64 1.2.0-1 [619 kB]
# Get:101 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu2 [578 kB]
# Get:102 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-utils amd64 1:7.7+6build2 [94.6 kB]
# Get:103 http://archive.ubuntu.com/ubuntu jammy/universe amd64 xfonts-cyrillic all 1:1.0.5 [386 kB]
# Get:104 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-scalable all 1:1.0.3-1.2ubuntu1 [306 kB]
# Get:105 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdca0 amd64 0.0.7-2 [88.2 kB]
# Get:106 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libgstreamer-plugins-bad1.0-0 amd64 1.20.3-0ubuntu1.1 [489 kB]
# Get:107 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsbc1 amd64 1.5-3build2 [34.4 kB]
# Get:108 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libvo-aacenc0 amd64 0.1.3-2 [69.4 kB]
# Get:109 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libvo-amrwbenc0 amd64 0.1.3-2 [68.2 kB]
# Get:110 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 gstreamer1.0-plugins-bad amd64 1.20.3-0ubuntu1.1 [2,602 kB]
# Fetched 57.3 MB in 2s (37.8 MB/s)
# Extracting templates from packages: 100%
# Preconfiguring packages ...
# Selecting previously unselected package fonts-ipafont-gothic.
# (Reading database ... 117528 files and directories currently installed.)
# Preparing to unpack .../000-fonts-ipafont-gothic_00303-21ubuntu1_all.deb ...
# Unpacking fonts-ipafont-gothic (00303-21ubuntu1) ...
# Preparing to unpack .../001-libglib2.0-dev_2.72.4-0ubuntu2.7_amd64.deb ...
# Unpacking libglib2.0-dev:amd64 (2.72.4-0ubuntu2.7) over (2.72.4-0ubuntu2.6) ...
# Preparing to unpack .../002-libglib2.0-dev-bin_2.72.4-0ubuntu2.7_amd64.deb ...
# Unpacking libglib2.0-dev-bin (2.72.4-0ubuntu2.7) over (2.72.4-0ubuntu2.6) ...
# Preparing to unpack .../003-libglib2.0-bin_2.72.4-0ubuntu2.7_amd64.deb ...
# Unpacking libglib2.0-bin (2.72.4-0ubuntu2.7) over (2.72.4-0ubuntu2.6) ...
# Preparing to unpack .../004-libglib2.0-0_2.72.4-0ubuntu2.7_amd64.deb ...
# Unpacking libglib2.0-0:amd64 (2.72.4-0ubuntu2.7) over (2.72.4-0ubuntu2.6) ...
# Selecting previously unselected package libtext-iconv-perl.
# Preparing to unpack .../005-libtext-iconv-perl_1.7-7build3_amd64.deb ...
# Unpacking libtext-iconv-perl (1.7-7build3) ...
# Selecting previously unselected package dictionaries-common.
# Preparing to unpack .../006-dictionaries-common_1.28.14_all.deb ...
# Adding 'diversion of /usr/share/dict/words to /usr/share/dict/words.pre-dictionaries-common by dictionaries-common'
# Unpacking dictionaries-common (1.28.14) ...
# Selecting previously unselected package fonts-freefont-ttf.
# Preparing to unpack .../007-fonts-freefont-ttf_20120503-10build1_all.deb ...
# Unpacking fonts-freefont-ttf (20120503-10build1) ...
# Selecting previously unselected package fonts-noto-color-emoji.
# Preparing to unpack .../008-fonts-noto-color-emoji_2.047-0ubuntu0.22.04.1_all.deb ...
# Unpacking fonts-noto-color-emoji (2.047-0ubuntu0.22.04.1) ...
# Selecting previously unselected package fonts-tlwg-loma-otf.
# Preparing to unpack .../009-fonts-tlwg-loma-otf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-loma-otf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-unifont.
# Preparing to unpack .../010-fonts-unifont_1%3a14.0.01-1_all.deb ...
# Unpacking fonts-unifont (1:14.0.01-1) ...
# Selecting previously unselected package fonts-wqy-zenhei.
# Preparing to unpack .../011-fonts-wqy-zenhei_0.9.45-8_all.deb ...
# Unpacking fonts-wqy-zenhei (0.9.45-8) ...
# Selecting previously unselected package libproxy1v5:amd64.
# Preparing to unpack .../012-libproxy1v5_0.4.17-2_amd64.deb ...
# Unpacking libproxy1v5:amd64 (0.4.17-2) ...
# Selecting previously unselected package glib-networking-common.
# Preparing to unpack .../013-glib-networking-common_2.72.0-1_all.deb ...
# Unpacking glib-networking-common (2.72.0-1) ...
# Selecting previously unselected package glib-networking-services.
# Preparing to unpack .../014-glib-networking-services_2.72.0-1_amd64.deb ...
# Unpacking glib-networking-services (2.72.0-1) ...
# Selecting previously unselected package session-migration.
# Preparing to unpack .../015-session-migration_0.3.6_amd64.deb ...
# Unpacking session-migration (0.3.6) ...
# Selecting previously unselected package gsettings-desktop-schemas.
# Preparing to unpack .../016-gsettings-desktop-schemas_42.0-1ubuntu1_all.deb ...
# Unpacking gsettings-desktop-schemas (42.0-1ubuntu1) ...
# Selecting previously unselected package glib-networking:amd64.
# Preparing to unpack .../017-glib-networking_2.72.0-1_amd64.deb ...
# Unpacking glib-networking:amd64 (2.72.0-1) ...
# Selecting previously unselected package liborc-0.4-0:amd64.
# Preparing to unpack .../018-liborc-0.4-0_1%3a0.4.32-2ubuntu0.1_amd64.deb ...
# Unpacking liborc-0.4-0:amd64 (1:0.4.32-2ubuntu0.1) ...
# Selecting previously unselected package libgstreamer-plugins-base1.0-0:amd64.
# Preparing to unpack .../019-libgstreamer-plugins-base1.0-0_1.20.1-1ubuntu0.5_amd64.deb ...
# Unpacking libgstreamer-plugins-base1.0-0:amd64 (1.20.1-1ubuntu0.5) ...
# Selecting previously unselected package gstreamer1.0-libav:amd64.
# Preparing to unpack .../020-gstreamer1.0-libav_1.20.3-0ubuntu1_amd64.deb ...
# Unpacking gstreamer1.0-libav:amd64 (1.20.3-0ubuntu1) ...
# Selecting previously unselected package libcdparanoia0:amd64.
# Preparing to unpack .../021-libcdparanoia0_3.10.2+debian-14build2_amd64.deb ...
# Unpacking libcdparanoia0:amd64 (3.10.2+debian-14build2) ...
# Selecting previously unselected package libvisual-0.4-0:amd64.
# Preparing to unpack .../022-libvisual-0.4-0_0.4.0-17build2_amd64.deb ...
# Unpacking libvisual-0.4-0:amd64 (0.4.0-17build2) ...
# Selecting previously unselected package gstreamer1.0-plugins-base:amd64.
# Preparing to unpack .../023-gstreamer1.0-plugins-base_1.20.1-1ubuntu0.5_amd64.deb ...
# Unpacking gstreamer1.0-plugins-base:amd64 (1.20.1-1ubuntu0.5) ...
# Selecting previously unselected package libaa1:amd64.
# Preparing to unpack .../024-libaa1_1.4p5-50build1_amd64.deb ...
# Unpacking libaa1:amd64 (1.4p5-50build1) ...
# Selecting previously unselected package libdv4:amd64.
# Preparing to unpack .../025-libdv4_1.0.0-14build1_amd64.deb ...
# Unpacking libdv4:amd64 (1.0.0-14build1) ...
# Selecting previously unselected package libgstreamer-plugins-good1.0-0:amd64.
# Preparing to unpack .../026-libgstreamer-plugins-good1.0-0_1.20.3-0ubuntu1.4_amd64.deb ...
# Unpacking libgstreamer-plugins-good1.0-0:amd64 (1.20.3-0ubuntu1.4) ...
# Selecting previously unselected package libgudev-1.0-0:amd64.
# Preparing to unpack .../027-libgudev-1.0-0_1%3a237-2build1_amd64.deb ...
# Unpacking libgudev-1.0-0:amd64 (1:237-2build1) ...
# Selecting previously unselected package libshout3:amd64.
# Preparing to unpack .../028-libshout3_2.4.5-1build3_amd64.deb ...
# Unpacking libshout3:amd64 (2.4.5-1build3) ...
# Selecting previously unselected package libtag1v5-vanilla:amd64.
# Preparing to unpack .../029-libtag1v5-vanilla_1.11.1+dfsg.1-3ubuntu3_amd64.deb ...
# Unpacking libtag1v5-vanilla:amd64 (1.11.1+dfsg.1-3ubuntu3) ...
# Selecting previously unselected package libtag1v5:amd64.
# Preparing to unpack .../030-libtag1v5_1.11.1+dfsg.1-3ubuntu3_amd64.deb ...
# Unpacking libtag1v5:amd64 (1.11.1+dfsg.1-3ubuntu3) ...
# Selecting previously unselected package libv4lconvert0:amd64.
# Preparing to unpack .../031-libv4lconvert0_1.22.1-2build1_amd64.deb ...
# Unpacking libv4lconvert0:amd64 (1.22.1-2build1) ...
# Selecting previously unselected package libv4l-0:amd64.
# Preparing to unpack .../032-libv4l-0_1.22.1-2build1_amd64.deb ...
# Unpacking libv4l-0:amd64 (1.22.1-2build1) ...
# Selecting previously unselected package libwavpack1:amd64.
# Preparing to unpack .../033-libwavpack1_5.4.0-1build2_amd64.deb ...
# Unpacking libwavpack1:amd64 (5.4.0-1build2) ...
# Selecting previously unselected package libsoup2.4-common.
# Preparing to unpack .../034-libsoup2.4-common_2.74.2-3ubuntu0.6_all.deb ...
# Unpacking libsoup2.4-common (2.74.2-3ubuntu0.6) ...
# Selecting previously unselected package libsoup2.4-1:amd64.
# Preparing to unpack .../035-libsoup2.4-1_2.74.2-3ubuntu0.6_amd64.deb ...
# Unpacking libsoup2.4-1:amd64 (2.74.2-3ubuntu0.6) ...
# Selecting previously unselected package gstreamer1.0-plugins-good:amd64.
# Preparing to unpack .../036-gstreamer1.0-plugins-good_1.20.3-0ubuntu1.4_amd64.deb ...
# Unpacking gstreamer1.0-plugins-good:amd64 (1.20.3-0ubuntu1.4) ...
# Selecting previously unselected package hunspell-en-us.
# Preparing to unpack .../037-hunspell-en-us_1%3a2020.12.07-2_all.deb ...
# Unpacking hunspell-en-us (1:2020.12.07-2) ...
# Selecting previously unselected package libabsl20210324:amd64.
# Preparing to unpack .../038-libabsl20210324_0~20210324.2-2ubuntu0.2_amd64.deb ...
# Unpacking libabsl20210324:amd64 (0~20210324.2-2ubuntu0.2) ...
# Selecting previously unselected package libaspell15:amd64.
# Preparing to unpack .../039-libaspell15_0.60.8-4build1_amd64.deb ...
# Unpacking libaspell15:amd64 (0.60.8-4build1) ...
# Selecting previously unselected package libatk1.0-data.
# Preparing to unpack .../040-libatk1.0-data_2.36.0-3build1_all.deb ...
# Unpacking libatk1.0-data (2.36.0-3build1) ...
# Selecting previously unselected package libatk1.0-0:amd64.
# Preparing to unpack .../041-libatk1.0-0_2.36.0-3build1_amd64.deb ...
# Unpacking libatk1.0-0:amd64 (2.36.0-3build1) ...
# Selecting previously unselected package libatspi2.0-0:amd64.
# Preparing to unpack .../042-libatspi2.0-0_2.44.0-3_amd64.deb ...
# Unpacking libatspi2.0-0:amd64 (2.44.0-3) ...
# Selecting previously unselected package libatk-bridge2.0-0:amd64.
# Preparing to unpack .../043-libatk-bridge2.0-0_2.38.0-3_amd64.deb ...
# Unpacking libatk-bridge2.0-0:amd64 (2.38.0-3) ...
# Selecting previously unselected package libgav1-0:amd64.
# Preparing to unpack .../044-libgav1-0_0.17.0-1build1_amd64.deb ...
# Unpacking libgav1-0:amd64 (0.17.0-1build1) ...
# Selecting previously unselected package libyuv0:amd64.
# Preparing to unpack .../045-libyuv0_0.0~git20220104.b91df1a-2_amd64.deb ...
# Unpacking libyuv0:amd64 (0.0~git20220104.b91df1a-2) ...
# Selecting previously unselected package libavif13:amd64.
# Preparing to unpack .../046-libavif13_0.9.3-3_amd64.deb ...
# Unpacking libavif13:amd64 (0.9.3-3) ...
# Selecting previously unselected package libdbus-glib-1-2:amd64.
# Preparing to unpack .../047-libdbus-glib-1-2_0.112-2build1_amd64.deb ...
# Unpacking libdbus-glib-1-2:amd64 (0.112-2build1) ...
# Selecting previously unselected package libdvdread8:amd64.
# Preparing to unpack .../048-libdvdread8_6.1.2-1_amd64.deb ...
# Unpacking libdvdread8:amd64 (6.1.2-1) ...
# Selecting previously unselected package libdvdnav4:amd64.
# Preparing to unpack .../049-libdvdnav4_6.1.1-1_amd64.deb ...
# Unpacking libdvdnav4:amd64 (6.1.1-1) ...
# Selecting previously unselected package libhunspell-1.7-0:amd64.
# Preparing to unpack .../050-libhunspell-1.7-0_1.7.0-4build1_amd64.deb ...
# Unpacking libhunspell-1.7-0:amd64 (1.7.0-4build1) ...
# Selecting previously unselected package libenchant-2-2:amd64.
# Preparing to unpack .../051-libenchant-2-2_2.3.2-1ubuntu2_amd64.deb ...
# Unpacking libenchant-2-2:amd64 (2.3.2-1ubuntu2) ...
# Selecting previously unselected package libfaad2:amd64.
# Preparing to unpack .../052-libfaad2_2.10.0-2_amd64.deb ...
# Unpacking libfaad2:amd64 (2.10.0-2) ...
# Selecting previously unselected package libffi7:amd64.
# Preparing to unpack .../053-libffi7_3.3-5ubuntu1_amd64.deb ...
# Unpacking libffi7:amd64 (3.3-5ubuntu1) ...
# Selecting previously unselected package libinstpatch-1.0-2:amd64.
# Preparing to unpack .../054-libinstpatch-1.0-2_1.1.6-1_amd64.deb ...
# Unpacking libinstpatch-1.0-2:amd64 (1.1.6-1) ...
# Selecting previously unselected package timgm6mb-soundfont.
# Preparing to unpack .../055-timgm6mb-soundfont_1.3-5_all.deb ...
# Unpacking timgm6mb-soundfont (1.3-5) ...
# Selecting previously unselected package libfluidsynth3:amd64.
# Preparing to unpack .../056-libfluidsynth3_2.2.5-1_amd64.deb ...
# Unpacking libfluidsynth3:amd64 (2.2.5-1) ...
# Selecting previously unselected package libfreeaptx0:amd64.
# Preparing to unpack .../057-libfreeaptx0_0.1.1-1_amd64.deb ...
# Unpacking libfreeaptx0:amd64 (0.1.1-1) ...
# Selecting previously unselected package libgssdp-1.2-0:amd64.
# Preparing to unpack .../058-libgssdp-1.2-0_1.4.0.1-2build1_amd64.deb ...
# Unpacking libgssdp-1.2-0:amd64 (1.4.0.1-2build1) ...
# Selecting previously unselected package libgstreamer-gl1.0-0:amd64.
# Preparing to unpack .../059-libgstreamer-gl1.0-0_1.20.1-1ubuntu0.5_amd64.deb ...
# Unpacking libgstreamer-gl1.0-0:amd64 (1.20.1-1ubuntu0.5) ...
# Selecting previously unselected package libxcomposite1:amd64.
# Preparing to unpack .../060-libxcomposite1_1%3a0.4.5-1build2_amd64.deb ...
# Unpacking libxcomposite1:amd64 (1:0.4.5-1build2) ...
# Selecting previously unselected package libgtk-3-common.
# Preparing to unpack .../061-libgtk-3-common_3.24.33-1ubuntu2.2_all.deb ...
# Unpacking libgtk-3-common (3.24.33-1ubuntu2.2) ...
# Selecting previously unselected package libgtk-3-0:amd64.
# Preparing to unpack .../062-libgtk-3-0_3.24.33-1ubuntu2.2_amd64.deb ...
# Unpacking libgtk-3-0:amd64 (3.24.33-1ubuntu2.2) ...
# Selecting previously unselected package libgupnp-1.2-1:amd64.
# Preparing to unpack .../063-libgupnp-1.2-1_1.4.3-1_amd64.deb ...
# Unpacking libgupnp-1.2-1:amd64 (1.4.3-1) ...
# Selecting previously unselected package libgupnp-igd-1.0-4:amd64.
# Preparing to unpack .../064-libgupnp-igd-1.0-4_1.2.0-1build1_amd64.deb ...
# Unpacking libgupnp-igd-1.0-4:amd64 (1.2.0-1build1) ...
# Selecting previously unselected package libharfbuzz-icu0:amd64.
# Preparing to unpack .../065-libharfbuzz-icu0_2.7.4-1ubuntu3.2_amd64.deb ...
# Unpacking libharfbuzz-icu0:amd64 (2.7.4-1ubuntu3.2) ...
# Selecting previously unselected package libhyphen0:amd64.
# Preparing to unpack .../066-libhyphen0_2.8.8-7build2_amd64.deb ...
# Unpacking libhyphen0:amd64 (2.8.8-7build2) ...
# Selecting previously unselected package libilmbase25:amd64.
# Preparing to unpack .../067-libilmbase25_2.5.7-2_amd64.deb ...
# Unpacking libilmbase25:amd64 (2.5.7-2) ...
# Selecting previously unselected package libjson-glib-1.0-common.
# Preparing to unpack .../068-libjson-glib-1.0-common_1.6.6-1build1_all.deb ...
# Unpacking libjson-glib-1.0-common (1.6.6-1build1) ...
# Selecting previously unselected package libjson-glib-1.0-0:amd64.
# Preparing to unpack .../069-libjson-glib-1.0-0_1.6.6-1build1_amd64.deb ...
# Unpacking libjson-glib-1.0-0:amd64 (1.6.6-1build1) ...
# Selecting previously unselected package libkate1:amd64.
# Preparing to unpack .../070-libkate1_0.4.1-11build1_amd64.deb ...
# Unpacking libkate1:amd64 (0.4.1-11build1) ...
# Selecting previously unselected package libldacbt-enc2:amd64.
# Preparing to unpack .../071-libldacbt-enc2_2.0.2.3+git20200429+ed310a0-4_amd64.deb ...
# Unpacking libldacbt-enc2:amd64 (2.0.2.3+git20200429+ed310a0-4) ...
# Selecting previously unselected package libltc11:amd64.
# Preparing to unpack .../072-libltc11_1.3.1-1_amd64.deb ...
# Unpacking libltc11:amd64 (1.3.1-1) ...
# Selecting previously unselected package libevdev2:amd64.
# Preparing to unpack .../073-libevdev2_1.12.1+dfsg-1_amd64.deb ...
# Unpacking libevdev2:amd64 (1.12.1+dfsg-1) ...
# Selecting previously unselected package libmanette-0.2-0:amd64.
# Preparing to unpack .../074-libmanette-0.2-0_0.2.6-3build1_amd64.deb ...
# Unpacking libmanette-0.2-0:amd64 (0.2.6-3build1) ...
# Selecting previously unselected package libmjpegutils-2.1-0:amd64.
# Preparing to unpack .../075-libmjpegutils-2.1-0_1%3a2.1.0+debian-6build1_amd64.deb ...
# Unpacking libmjpegutils-2.1-0:amd64 (1:2.1.0+debian-6build1) ...
# Selecting previously unselected package libmodplug1:amd64.
# Preparing to unpack .../076-libmodplug1_1%3a0.8.9.0-3_amd64.deb ...
# Unpacking libmodplug1:amd64 (1:0.8.9.0-3) ...
# Selecting previously unselected package libmpcdec6:amd64.
# Preparing to unpack .../077-libmpcdec6_2%3a0.1~r495-2_amd64.deb ...
# Unpacking libmpcdec6:amd64 (2:0.1~r495-2) ...
# Selecting previously unselected package libmpeg2encpp-2.1-0:amd64.
# Preparing to unpack .../078-libmpeg2encpp-2.1-0_1%3a2.1.0+debian-6build1_amd64.deb ...
# Unpacking libmpeg2encpp-2.1-0:amd64 (1:2.1.0+debian-6build1) ...
# Selecting previously unselected package libmplex2-2.1-0:amd64.
# Preparing to unpack .../079-libmplex2-2.1-0_1%3a2.1.0+debian-6build1_amd64.deb ...
# Unpacking libmplex2-2.1-0:amd64 (1:2.1.0+debian-6build1) ...
# Selecting previously unselected package libnice10:amd64.
# Preparing to unpack .../080-libnice10_0.1.18-2_amd64.deb ...
# Unpacking libnice10:amd64 (0.1.18-2) ...
# Selecting previously unselected package libnotify4:amd64.
# Preparing to unpack .../081-libnotify4_0.7.9-3ubuntu5.22.04.1_amd64.deb ...
# Unpacking libnotify4:amd64 (0.7.9-3ubuntu5.22.04.1) ...
# Selecting previously unselected package libopenexr25:amd64.
# Preparing to unpack .../082-libopenexr25_2.5.7-1_amd64.deb ...
# Unpacking libopenexr25:amd64 (2.5.7-1) ...
# Selecting previously unselected package libopenh264-6:amd64.
# Preparing to unpack .../083-libopenh264-6_2.2.0+dfsg-2_amd64.deb ...
# Unpacking libopenh264-6:amd64 (2.2.0+dfsg-2) ...
# Selecting previously unselected package libopenni2-0:amd64.
# Preparing to unpack .../084-libopenni2-0_2.2.0.33+dfsg-15_amd64.deb ...
# Unpacking libopenni2-0:amd64 (2.2.0.33+dfsg-15) ...
# Selecting previously unselected package libqrencode4:amd64.
# Preparing to unpack .../085-libqrencode4_4.1.1-1_amd64.deb ...
# Unpacking libqrencode4:amd64 (4.1.1-1) ...
# Selecting previously unselected package libsecret-common.
# Preparing to unpack .../086-libsecret-common_0.20.5-2_all.deb ...
# Unpacking libsecret-common (0.20.5-2) ...
# Selecting previously unselected package libsecret-1-0:amd64.
# Preparing to unpack .../087-libsecret-1-0_0.20.5-2_amd64.deb ...
# Unpacking libsecret-1-0:amd64 (0.20.5-2) ...
# Selecting previously unselected package libsoundtouch1:amd64.
# Preparing to unpack .../088-libsoundtouch1_2.3.1+ds1-1_amd64.deb ...
# Unpacking libsoundtouch1:amd64 (2.3.1+ds1-1) ...
# Selecting previously unselected package libsoup-3.0-common.
# Preparing to unpack .../089-libsoup-3.0-common_3.0.7-0ubuntu1_all.deb ...
# Unpacking libsoup-3.0-common (3.0.7-0ubuntu1) ...
# Selecting previously unselected package libsoup-3.0-0:amd64.
# Preparing to unpack .../090-libsoup-3.0-0_3.0.7-0ubuntu1_amd64.deb ...
# Unpacking libsoup-3.0-0:amd64 (3.0.7-0ubuntu1) ...
# Selecting previously unselected package libspandsp2:amd64.
# Preparing to unpack .../091-libspandsp2_0.0.6+dfsg-2_amd64.deb ...
# Unpacking libspandsp2:amd64 (0.0.6+dfsg-2) ...
# Selecting previously unselected package libsrtp2-1:amd64.
# Preparing to unpack .../092-libsrtp2-1_2.4.2-2_amd64.deb ...
# Unpacking libsrtp2-1:amd64 (2.4.2-2) ...
# Selecting previously unselected package libwebrtc-audio-processing1:amd64.
# Preparing to unpack .../093-libwebrtc-audio-processing1_0.3.1-0ubuntu5_amd64.deb ...
# Unpacking libwebrtc-audio-processing1:amd64 (0.3.1-0ubuntu5) ...
# Selecting previously unselected package libwildmidi2:amd64.
# Preparing to unpack .../094-libwildmidi2_0.4.3-1_amd64.deb ...
# Unpacking libwildmidi2:amd64 (0.4.3-1) ...
# Selecting previously unselected package libwoff1:amd64.
# Preparing to unpack .../095-libwoff1_1.0.2-1build4_amd64.deb ...
# Unpacking libwoff1:amd64 (1.0.2-1build4) ...
# Preparing to unpack .../096-libxslt1.1_1.1.34-4ubuntu0.22.04.5_amd64.deb ...
# Unpacking libxslt1.1:amd64 (1.1.34-4ubuntu0.22.04.5) over (1.1.34-4ubuntu0.22.04.4) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../097-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package libzbar0:amd64.
# Preparing to unpack .../098-libzbar0_0.23.92-4build2_amd64.deb ...
# Unpacking libzbar0:amd64 (0.23.92-4build2) ...
# Selecting previously unselected package libzxingcore1:amd64.
# Preparing to unpack .../099-libzxingcore1_1.2.0-1_amd64.deb ...
# Unpacking libzxingcore1:amd64 (1.2.0-1) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../100-xfonts-encodings_1%3a1.0.5-0ubuntu2_all.deb ...
# Unpacking xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../101-xfonts-utils_1%3a7.7+6build2_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6build2) ...
# Selecting previously unselected package xfonts-cyrillic.
# Preparing to unpack .../102-xfonts-cyrillic_1%3a1.0.5_all.deb ...
# Unpacking xfonts-cyrillic (1:1.0.5) ...
# Selecting previously unselected package xfonts-scalable.
# Preparing to unpack .../103-xfonts-scalable_1%3a1.0.3-1.2ubuntu1_all.deb ...
# Unpacking xfonts-scalable (1:1.0.3-1.2ubuntu1) ...
# Selecting previously unselected package libdca0:amd64.
# Preparing to unpack .../104-libdca0_0.0.7-2_amd64.deb ...
# Unpacking libdca0:amd64 (0.0.7-2) ...
# Selecting previously unselected package libgstreamer-plugins-bad1.0-0:amd64.
# Preparing to unpack .../105-libgstreamer-plugins-bad1.0-0_1.20.3-0ubuntu1.1_amd64.deb ...
# Unpacking libgstreamer-plugins-bad1.0-0:amd64 (1.20.3-0ubuntu1.1) ...
# Selecting previously unselected package libsbc1:amd64.
# Preparing to unpack .../106-libsbc1_1.5-3build2_amd64.deb ...
# Unpacking libsbc1:amd64 (1.5-3build2) ...
# Selecting previously unselected package libvo-aacenc0:amd64.
# Preparing to unpack .../107-libvo-aacenc0_0.1.3-2_amd64.deb ...
# Unpacking libvo-aacenc0:amd64 (0.1.3-2) ...
# Selecting previously unselected package libvo-amrwbenc0:amd64.
# Preparing to unpack .../108-libvo-amrwbenc0_0.1.3-2_amd64.deb ...
# Unpacking libvo-amrwbenc0:amd64 (0.1.3-2) ...
# Selecting previously unselected package gstreamer1.0-plugins-bad:amd64.
# Preparing to unpack .../109-gstreamer1.0-plugins-bad_1.20.3-0ubuntu1.1_amd64.deb ...
# Unpacking gstreamer1.0-plugins-bad:amd64 (1.20.3-0ubuntu1.1) ...
# Setting up libtext-iconv-perl (1.7-7build3) ...
# Setting up libfreeaptx0:amd64 (0.1.1-1) ...
# Setting up libmodplug1:amd64 (1:0.8.9.0-3) ...
# Setting up libcdparanoia0:amd64 (3.10.2+debian-14build2) ...
# Setting up libvo-amrwbenc0:amd64 (0.1.3-2) ...
# Setting up libsbc1:amd64 (1.5-3build2) ...
# Setting up libproxy1v5:amd64 (0.4.17-2) ...
# Setting up libtag1v5-vanilla:amd64 (1.11.1+dfsg.1-3ubuntu3) ...
# Setting up libkate1:amd64 (0.4.1-11build1) ...
# Setting up libharfbuzz-icu0:amd64 (2.7.4-1ubuntu3.2) ...
# Setting up libopenni2-0:amd64 (2.2.0.33+dfsg-15) ...
# Setting up libwoff1:amd64 (1.0.2-1build4) ...
# Setting up libqrencode4:amd64 (4.1.1-1) ...
# Setting up libhyphen0:amd64 (2.8.8-7build2) ...
# Setting up dictionaries-common (1.28.14) ...
# Setting up fonts-noto-color-emoji (2.047-0ubuntu0.22.04.1) ...
# Setting up libvisual-0.4-0:amd64 (0.4.0-17build2) ...
# Setting up libglib2.0-0:amd64 (2.72.4-0ubuntu2.7) ...
# Setting up libaspell15:amd64 (0.60.8-4build1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up libsrtp2-1:amd64 (2.4.2-2) ...
# Setting up libffi7:amd64 (3.3-5ubuntu1) ...
# Setting up libldacbt-enc2:amd64 (2.0.2.3+git20200429+ed310a0-4) ...
# Setting up fonts-wqy-zenhei (0.9.45-8) ...
# Setting up libwebrtc-audio-processing1:amd64 (0.3.1-0ubuntu5) ...
# Setting up fonts-freefont-ttf (20120503-10build1) ...
# Setting up libglib2.0-bin (2.72.4-0ubuntu2.7) ...
# Setting up libilmbase25:amd64 (2.5.7-2) ...
# Setting up libatspi2.0-0:amd64 (2.44.0-3) ...
# Setting up libsoup-3.0-common (3.0.7-0ubuntu1) ...
# Setting up libmpcdec6:amd64 (2:0.1~r495-2) ...
# Setting up libspandsp2:amd64 (0.0.6+dfsg-2) ...
# Setting up libvo-aacenc0:amd64 (0.1.3-2) ...
# Setting up libopenexr25:amd64 (2.5.7-1) ...
# Setting up libsoundtouch1:amd64 (2.3.1+ds1-1) ...
# Setting up fonts-tlwg-loma-otf (1:0.7.3-1) ...
# Setting up libdvdread8:amd64 (6.1.2-1) ...
# Setting up libdbus-glib-1-2:amd64 (0.112-2build1) ...
# Setting up libnotify4:amd64 (0.7.9-3ubuntu5.22.04.1) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Setting up libfaad2:amd64 (2.10.0-2) ...
# Setting up libshout3:amd64 (2.4.5-1build3) ...
# Setting up liborc-0.4-0:amd64 (1:0.4.32-2ubuntu0.1) ...
# Setting up libabsl20210324:amd64 (0~20210324.2-2ubuntu0.2) ...
# Setting up libltc11:amd64 (1.3.1-1) ...
# Setting up libsoup2.4-common (2.74.2-3ubuntu0.6) ...
# Setting up libatk1.0-data (2.36.0-3build1) ...
# Setting up libtag1v5:amd64 (1.11.1+dfsg.1-3ubuntu3) ...
# Setting up libdv4:amd64 (1.0.0-14build1) ...
# Setting up fonts-ipafont-gothic (00303-21ubuntu1) ...
# update-alternatives: using /usr/share/fonts/opentype/ipafont-gothic/ipag.ttf to provide /usr/share/fonts/truetype/fonts-japanese-gothic.ttf (fonts-japanese-gothic.ttf) in auto mode
# Setting up libwildmidi2:amd64 (0.4.3-1) ...
# Setting up libopenh264-6:amd64 (2.2.0+dfsg-2) ...
# Setting up libwavpack1:amd64 (5.4.0-1build2) ...
# Setting up libzxingcore1:amd64 (1.2.0-1) ...
# Setting up libv4lconvert0:amd64 (1.22.1-2build1) ...
# Setting up libxslt1.1:amd64 (1.1.34-4ubuntu0.22.04.5) ...
# Setting up hunspell-en-us (1:2020.12.07-2) ...
# Setting up libdca0:amd64 (0.0.7-2) ...
# Setting up libjson-glib-1.0-common (1.6.6-1build1) ...
# Setting up libatk1.0-0:amd64 (2.36.0-3build1) ...
# Setting up libhunspell-1.7-0:amd64 (1.7.0-4build1) ...
# Setting up glib-networking-common (2.72.0-1) ...
# Setting up timgm6mb-soundfont (1.3-5) ...
# update-alternatives: using /usr/share/sounds/sf2/TimGM6mb.sf2 to provide /usr/share/sounds/sf2/default-GM.sf2 (default-GM.sf2) in auto mode
# update-alternatives: using /usr/share/sounds/sf2/TimGM6mb.sf2 to provide /usr/share/sounds/sf3/default-GM.sf3 (default-GM.sf3) in auto mode
# Setting up libyuv0:amd64 (0.0~git20220104.b91df1a-2) ...
# Setting up libxcomposite1:amd64 (1:0.4.5-1build2) ...
# Setting up libevdev2:amd64 (1.12.1+dfsg-1) ...
# Setting up libinstpatch-1.0-2:amd64 (1.1.6-1) ...
# Setting up libmjpegutils-2.1-0:amd64 (1:2.1.0+debian-6build1) ...
# Setting up libgudev-1.0-0:amd64 (1:237-2build1) ...
# Setting up libsecret-common (0.20.5-2) ...
# Setting up libgtk-3-common (3.24.33-1ubuntu2.2) ...
# Setting up libfluidsynth3:amd64 (2.2.5-1) ...
# Setting up libdvdnav4:amd64 (6.1.1-1) ...
# Setting up fonts-unifont (1:14.0.01-1) ...
# Setting up libaa1:amd64 (1.4p5-50build1) ...
# Setting up libglib2.0-dev-bin (2.72.4-0ubuntu2.7) ...
# Setting up glib-networking-services (2.72.0-1) ...
# Setting up session-migration (0.3.6) ...
# Created symlink /etc/systemd/user/graphical-session-pre.target.wants/session-migration.service → /usr/lib/systemd/user/session-migration.service.
# Setting up libenchant-2-2:amd64 (2.3.2-1ubuntu2) ...
# Setting up libmanette-0.2-0:amd64 (0.2.6-3build1) ...
# Setting up libgstreamer-plugins-base1.0-0:amd64 (1.20.1-1ubuntu0.5) ...
# Setting up xfonts-utils (1:7.7+6build2) ...
# Setting up libjson-glib-1.0-0:amd64 (1.6.6-1build1) ...
# Setting up libv4l-0:amd64 (1.22.1-2build1) ...
# Setting up libatk-bridge2.0-0:amd64 (2.38.0-3) ...
# Setting up libgstreamer-plugins-bad1.0-0:amd64 (1.20.3-0ubuntu1.1) ...
# Setting up libsecret-1-0:amd64 (0.20.5-2) ...
# Setting up libgstreamer-plugins-good1.0-0:amd64 (1.20.3-0ubuntu1.4) ...
# Setting up libgstreamer-gl1.0-0:amd64 (1.20.1-1ubuntu0.5) ...
# Setting up gstreamer1.0-plugins-base:amd64 (1.20.1-1ubuntu0.5) ...
# Setting up libglib2.0-dev:amd64 (2.72.4-0ubuntu2.7) ...
# Setting up libgav1-0:amd64 (0.17.0-1build1) ...
# Setting up libmpeg2encpp-2.1-0:amd64 (1:2.1.0+debian-6build1) ...
# Setting up libavif13:amd64 (0.9.3-3) ...
# Setting up xfonts-cyrillic (1:1.0.5) ...
# Setting up libmplex2-2.1-0:amd64 (1:2.1.0+debian-6build1) ...
# Setting up gstreamer1.0-libav:amd64 (1.20.3-0ubuntu1) ...
# Setting up xfonts-scalable (1:1.0.3-1.2ubuntu1) ...
# Setting up gsettings-desktop-schemas (42.0-1ubuntu1) ...
# Setting up libzbar0:amd64 (0.23.92-4build2) ...
# Setting up libgtk-3-0:amd64 (3.24.33-1ubuntu2.2) ...
# Setting up glib-networking:amd64 (2.72.0-1) ...
# Setting up libsoup2.4-1:amd64 (2.74.2-3ubuntu0.6) ...
# Setting up gstreamer1.0-plugins-good:amd64 (1.20.3-0ubuntu1.4) ...
# Setting up libsoup-3.0-0:amd64 (3.0.7-0ubuntu1) ...
# Setting up libgssdp-1.2-0:amd64 (1.4.0.1-2build1) ...
# Setting up libgupnp-1.2-1:amd64 (1.4.3-1) ...
# Setting up libgupnp-igd-1.0-4:amd64 (1.2.0-1build1) ...
# Setting up libnice10:amd64 (0.1.18-2) ...
# Setting up gstreamer1.0-plugins-bad:amd64 (1.20.3-0ubuntu1.1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.11) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for dictionaries-common (1.28.14) ...

# %%
import os
os.environ['PATH'] += ':/content/allure-2.24.1/bin'

# %%
# Cell 2: Create Project Structure
import os

# Create directories
os.makedirs('saucedemo_tests', exist_ok=True)
os.makedirs('allure-results', exist_ok=True)

# %%
# Cell 3: Create Test File
test_content = '''import pytest
import allure
from playwright.sync_api import Page, expect
import time


class TestSauceDemo:
    """Test suite for SauceDemo website"""

    BASE_URL = "https://www.saucedemo.com/"

    @pytest.fixture(autouse=True)
    def setup(self, page: Page):
        """Setup: Navigate to SauceDemo before each test"""
        page.goto(self.BASE_URL)
        page.set_viewport_size({"width": 1920, "height": 1080})
        self.page = page
        yield
        # Teardown happens automatically

    def login(self, username: str, password: str):
        """Helper method to perform login"""
        self.page.fill("#user-name", username)
        self.page.fill("#password", password)
        self.page.click("#login-button")

    def reset_app_state(self):
        """Helper method to reset application state"""
        self.page.click("#react-burger-menu-btn")
        self.page.wait_for_selector("#reset_sidebar_link", state="visible")
        self.page.click("#reset_sidebar_link")
        time.sleep(1)
        self.page.click("#react-burger-cross-btn")
        time.sleep(0.5)

    def logout(self):
        """Helper method to logout"""
        self.page.click("#react-burger-menu-btn")
        self.page.wait_for_selector("#logout_sidebar_link", state="visible")
        self.page.click("#logout_sidebar_link")

    @allure.title("Q1: Verify locked out user error message")
    @allure.description("Test login with locked_out_user and verify the error message")
    @allure.severity(allure.severity_level.CRITICAL)
    @pytest.mark.q1
    def test_locked_out_user(self):
        """Q1: Try login with locked_out_user and verify the error message"""

        with allure.step("Attempt login with locked_out_user"):
            self.login("locked_out_user", "secret_sauce")

        with allure.step("Verify error message is displayed"):
            error_element = self.page.locator("[data-test='error']")
            expect(error_element).to_be_visible()

            actual_message = error_element.text_content()
            expected_message = "Epic sadface: Sorry, this user has been locked out."

            allure.attach(
                actual_message,
                name="Error Message",
                attachment_type=allure.attachment_type.TEXT
            )

            assert expected_message == actual_message, \\
                f"Expected: '{expected_message}', but got: '{actual_message}'"

        with allure.step("Capture screenshot of error"):
            screenshot = self.page.screenshot()
            allure.attach(
                screenshot,
                name="locked_out_user_error",
                attachment_type=allure.attachment_type.PNG
            )

        print(f"Q1 Test Passed: Error message verified - '{actual_message}'")

    @allure.title("Q2: Standard user complete purchase journey")
    @allure.description("Login with standard_user, add items, verify checkout and complete purchase")
    @allure.severity(allure.severity_level.CRITICAL)
    @pytest.mark.q2
    def test_standard_user_purchase(self):
        """Q2: Login with standard_user and complete purchase journey"""

        with allure.step("Login with standard_user"):
            self.login("standard_user", "secret_sauce")
            expect(self.page.locator(".inventory_list")).to_be_visible()

        with allure.step("Reset App State"):
            self.reset_app_state()

        product_names = []
        product_prices = []

        with allure.step("Add three items to cart"):
            products = self.page.locator(".inventory_item").all()

            for i in range(3):
                product = products[i]
                name = product.locator(".inventory_item_name").text_content()
                price_text = product.locator(".inventory_item_price").text_content()
                price = float(price_text.replace("$", ""))

                product_names.append(name)
                product_prices.append(price)

                # Click add to cart button
                product.locator("button[id^='add-to-cart']").click()

            allure.attach(
                f"Products: {', '.join(product_names)}\\nPrices: {product_prices}",
                name="Added Products",
                attachment_type=allure.attachment_type.TEXT
            )
            print(f"Added 3 products: {', '.join(product_names)}")

        with allure.step("Navigate to cart"):
            self.page.click(".shopping_cart_link")
            expect(self.page.locator(".cart_list")).to_be_visible()

        with allure.step("Proceed to checkout"):
            self.page.click("#checkout")

        with allure.step("Fill checkout information"):
            self.page.fill("#first-name", "John")
            self.page.fill("#last-name", "Doe")
            self.page.fill("#postal-code", "12345")
            self.page.click("#continue")

        with allure.step("Verify product names on final checkout page"):
            checkout_items = self.page.locator(".inventory_item_name").all()
            checkout_product_names = [item.text_content() for item in checkout_items]

            assert product_names == checkout_product_names, \\
                f"Product names mismatch. Expected: {product_names}, Got: {checkout_product_names}"

            print(f"Product names verified on checkout page")

        with allure.step("Verify total price"):
            item_total_text = self.page.locator(".summary_subtotal_label").text_content()
            item_total_value = float(item_total_text.replace("Item total: $", ""))

            expected_total = sum(product_prices)

            allure.attach(
                f"Expected Total: ${expected_total:.2f}\\nActual Total: ${item_total_value:.2f}",
                name="Price Verification",
                attachment_type=allure.attachment_type.TEXT
            )

            assert abs(expected_total - item_total_value) < 0.01, \\
                f"Total price mismatch. Expected: ${expected_total}, Got: ${item_total_value}"

            print(f"Total price verified: ${item_total_value}")

        with allure.step("Finish purchase"):
            self.page.click("#finish")

        with allure.step("Verify successful order message"):
            success_header = self.page.locator(".complete-header")
            expect(success_header).to_be_visible()

            actual_message = success_header.text_content()
            expected_message = "Thank you for your order!"

            screenshot = self.page.screenshot()
            allure.attach(
                screenshot,
                name="order_success",
                attachment_type=allure.attachment_type.PNG
            )

            assert expected_message == actual_message, \\
                f"Success message mismatch. Expected: '{expected_message}', Got: '{actual_message}'"

            print(f"Order successful: '{actual_message}'")

        with allure.step("Navigate back to products"):
            self.page.click("#back-to-products")

        with allure.step("Reset App State again"):
            self.reset_app_state()

        with allure.step("Logout"):
            self.logout()
            expect(self.page.locator("#login-button")).to_be_visible()

        print("Q2 Test Passed: Complete purchase journey successful")

    @allure.title("Q3: Performance glitch user purchase with filtering")
    @allure.description("Login with performance_glitch_user, filter products, and complete purchase")
    @allure.severity(allure.severity_level.CRITICAL)
    @pytest.mark.q3
    def test_performance_glitch_user_purchase(self):
        """Q3: Login with performance_glitch_user and complete purchase with filtering"""

        with allure.step("Login with performance_glitch_user"):
            self.login("performance_glitch_user", "secret_sauce")
            expect(self.page.locator(".inventory_list")).to_be_visible(timeout=10000)
            time.sleep(2)  # Wait for performance_glitch_user delay

        with allure.step("Reset App State"):
            self.reset_app_state()

        with allure.step("Filter by name (Z to A)"):
            self.page.select_option(".product_sort_container", "za")
            time.sleep(1)

        product_name = ""
        product_price = 0.0

        with allure.step("Select first product and add to cart"):
            first_product = self.page.locator(".inventory_item").first
            product_name = first_product.locator(".inventory_item_name").text_content()
            price_text = first_product.locator(".inventory_item_price").text_content()
            product_price = float(price_text.replace("$", ""))

            first_product.locator("button[id^='add-to-cart']").click()

            allure.attach(
                f"Product: {product_name}\\nPrice: ${product_price}",
                name="Selected Product",
                attachment_type=allure.attachment_type.TEXT
            )

            print(f"Added product: {product_name} - ${product_price}")

        with allure.step("Navigate to cart"):
            self.page.click(".shopping_cart_link")
            expect(self.page.locator(".cart_list")).to_be_visible()

        with allure.step("Proceed to checkout"):
            self.page.click("#checkout")

        with allure.step("Fill checkout information"):
            self.page.fill("#first-name", "Jane")
            self.page.fill("#last-name", "Smith")
            self.page.fill("#postal-code", "54321")
            self.page.click("#continue")

        with allure.step("Verify product name on final checkout page"):
            checkout_item = self.page.locator(".inventory_item_name").first
            checkout_product_name = checkout_item.text_content()

            assert product_name == checkout_product_name, \\
                f"Product name mismatch. Expected: {product_name}, Got: {checkout_product_name}"

            print(f"Product name verified: {checkout_product_name}")

        with allure.step("Verify total price"):
            item_total_text = self.page.locator(".summary_subtotal_label").text_content()
            item_total_value = float(item_total_text.replace("Item total: $", ""))

            allure.attach(
                f"Expected Total: ${product_price:.2f}\\nActual Total: ${item_total_value:.2f}",
                name="Price Verification",
                attachment_type=allure.attachment_type.TEXT
            )

            assert abs(product_price - item_total_value) < 0.01, \\
                f"Total price mismatch. Expected: ${product_price}, Got: ${item_total_value}"

            print(f"Total price verified: ${item_total_value}")

        with allure.step("Finish purchase"):
            self.page.click("#finish")

        with allure.step("Verify successful order message"):
            success_header = self.page.locator(".complete-header")
            expect(success_header).to_be_visible()

            actual_message = success_header.text_content()
            expected_message = "Thank you for your order!"

            screenshot = self.page.screenshot()
            allure.attach(
                screenshot,
                name="order_success_performance_user",
                attachment_type=allure.attachment_type.PNG
            )

            assert expected_message == actual_message, \\
                f"Success message mismatch. Expected: '{expected_message}', Got: '{actual_message}'"

            print(f"Order successful: '{actual_message}'")

        with allure.step("Navigate back to products"):
            self.page.click("#back-to-products")

        with allure.step("Reset App State again"):
            self.reset_app_state()

        with allure.step("Logout"):
            self.logout()
            expect(self.page.locator("#login-button")).to_be_visible()

        print("Q3 Test Passed: Performance glitch user purchase successful")
'''

with open('saucedemo_tests/test_saucedemo.py', 'w') as f:
    f.write(test_content)

print("Test file created: saucedemo_tests/test_saucedemo.py")
# Out:
# Test file created: saucedemo_tests/test_saucedemo.py

# %%
# Cell 4: Create pytest.ini
pytest_ini_content = '''[pytest]
markers =
    q1: marks tests for Question 1 (locked_out_user)
    q2: marks tests for Question 2 (standard_user purchase)
    q3: marks tests for Question 3 (performance_glitch_user purchase)

addopts =
    --alluredir=allure-results
    --headed
    -v
    -s
'''

with open('pytest.ini', 'w') as f:
    f.write(pytest_ini_content)

print("pytest.ini created")

# Cell 5: Create conftest.py for Playwright
conftest_content = '''import pytest
from playwright.sync_api import sync_playwright


@pytest.fixture(scope="function")
def page(browser):
    """Create a new page for each test"""
    context = browser.new_context(
        viewport={'width': 1920, 'height': 1080}
    )
    page = context.new_page()
    yield page
    context.close()


@pytest.fixture(scope="session")
def browser():
    """Create browser instance for the session"""
    with sync_playwright() as p:
        browser = p.chromium.launch(
            headless=True,
            args=['--no-sandbox', '--disable-dev-shm-usage']
        )
        yield browser
        browser.close()
'''

with open('saucedemo_tests/conftest.py', 'w') as f:
    f.write(conftest_content)

print("conftest.py created")
# Out:
# pytest.ini created
# conftest.py created

# %%
# Cell 6: Create requirements.txt
requirements_content = '''pytest==7.4.3
pytest-playwright==0.4.3
playwright==1.40.0
allure-pytest==2.13.2
pytest-html==4.1.1
'''

with open('requirements.txt', 'w') as f:
    f.write(requirements_content)

print("requirements.txt created")
# Out:
# requirements.txt created

# %%
# Cell 7: Run All Tests
print("\\n" + "="*60)
print("RUNNING ALL TESTS SEQUENTIALLY")
print("="*60 + "\\n")

# !pytest saucedemo_tests/test_saucedemo.py -v -s
# Out:
# \n============================================================
# RUNNING ALL TESTS SEQUENTIALLY
# ============================================================\n
# ============================= test session starts ==============================
# platform linux -- Python 3.12.12, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# metadata: {'Python': '3.12.12', 'Platform': 'Linux-6.6.105+-x86_64-with-glibc2.35', 'Packages': {'pytest': '8.4.2', 'pluggy': '1.6.0'}, 'Plugins': {'playwright': '0.7.2', 'allure-pytest': '2.15.3', 'base-url': '2.1.0', 'html': '4.1.1', 'metadata': '3.1.1', 'typeguard': '4.4.4', 'langsmith': '0.4.59', 'anyio': '4.12.0'}, 'Base URL': ''}
# rootdir: /content
# configfile: pytest.ini
# plugins: playwright-0.7.2, allure-pytest-2.15.3, base-url-2.1.0, html-4.1.1, metadata-3.1.1, typeguard-4.4.4, langsmith-0.4.59, anyio-4.12.0
# collected 3 items
#
# saucedemo_tests/test_saucedemo.py::TestSauceDemo::test_locked_out_user Q1 Test Passed: Error message verified - 'Epic sadface: Sorry, this user has been locked out.'
# PASSED
# saucedemo_tests/test_saucedemo.py::TestSauceDemo::test_standard_user_purchase Added 3 products: Sauce Labs Backpack, Sauce Labs Bike Light, Sauce Labs Bolt T-Shirt
# Product names verified on checkout page
# Total price verified: $55.97
# Order successful: 'Thank you for your order!'
# Q2 Test Passed: Complete purchase journey successful
# PASSED
# saucedemo_tests/test_saucedemo.py::TestSauceDemo::test_performance_glitch_user_purchase Added product: Test.allTheThings() T-Shirt (Red) - $15.99
# Product name verified: Test.allTheThings() T-Shirt (Red)
# Total price verified: $15.99
# Order successful: 'Thank you for your order!'
# Q3 Test Passed: Performance glitch user purchase successful
# PASSED
#
# ============================== 3 passed in 35.77s ==============================

# %%
# Cell 8: Run Q1 Only
print("\\n" + "="*60)
print("RUNNING Q1 ONLY")
print("="*60 + "\\n")

# !pytest saucedemo_tests/test_saucedemo.py::TestSauceDemo::test_locked_out_user -v -s
# Out:
# \n============================================================
# RUNNING Q1 ONLY
# ============================================================\n
# ============================= test session starts ==============================
# platform linux -- Python 3.12.12, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# metadata: {'Python': '3.12.12', 'Platform': 'Linux-6.6.105+-x86_64-with-glibc2.35', 'Packages': {'pytest': '8.4.2', 'pluggy': '1.6.0'}, 'Plugins': {'playwright': '0.7.2', 'allure-pytest': '2.15.3', 'base-url': '2.1.0', 'html': '4.1.1', 'metadata': '3.1.1', 'typeguard': '4.4.4', 'langsmith': '0.4.59', 'anyio': '4.12.0'}, 'Base URL': ''}
# rootdir: /content
# configfile: pytest.ini
# plugins: playwright-0.7.2, allure-pytest-2.15.3, base-url-2.1.0, html-4.1.1, metadata-3.1.1, typeguard-4.4.4, langsmith-0.4.59, anyio-4.12.0
# collected 1 item
#
# saucedemo_tests/test_saucedemo.py::TestSauceDemo::test_locked_out_user Q1 Test Passed: Error message verified - 'Epic sadface: Sorry, this user has been locked out.'
# PASSED
#
# ============================== 1 passed in 2.26s ===============================

# %%
# Cell 9: Run Q2 Only
print("\\n" + "="*60)
print("RUNNING Q2 ONLY")
print("="*60 + "\\n")

# !pytest saucedemo_tests/test_saucedemo.py::TestSauceDemo::test_standard_user_purchase -v -s
# Out:
# \n============================================================
# RUNNING Q2 ONLY
# ============================================================\n
# ============================= test session starts ==============================
# platform linux -- Python 3.12.12, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# metadata: {'Python': '3.12.12', 'Platform': 'Linux-6.6.105+-x86_64-with-glibc2.35', 'Packages': {'pytest': '8.4.2', 'pluggy': '1.6.0'}, 'Plugins': {'playwright': '0.7.2', 'allure-pytest': '2.15.3', 'base-url': '2.1.0', 'html': '4.1.1', 'metadata': '3.1.1', 'typeguard': '4.4.4', 'langsmith': '0.4.59', 'anyio': '4.12.0'}, 'Base URL': ''}
# rootdir: /content
# configfile: pytest.ini
# plugins: playwright-0.7.2, allure-pytest-2.15.3, base-url-2.1.0, html-4.1.1, metadata-3.1.1, typeguard-4.4.4, langsmith-0.4.59, anyio-4.12.0
# collected 1 item
#
# saucedemo_tests/test_saucedemo.py::TestSauceDemo::test_standard_user_purchase Added 3 products: Sauce Labs Backpack, Sauce Labs Bike Light, Sauce Labs Bolt T-Shirt
# Product names verified on checkout page
# Total price verified: $55.97
# Order successful: 'Thank you for your order!'
# Q2 Test Passed: Complete purchase journey successful
# PASSED
#
# ============================== 1 passed in 8.52s ===============================

# %%
# Cell 10: Run Q3 Only
print("\\n" + "="*60)
print("RUNNING Q3 ONLY")
print("="*60 + "\\n")

# !pytest saucedemo_tests/test_saucedemo.py::TestSauceDemo::test_performance_glitch_user_purchase -v -s
# Out:
# \n============================================================
# RUNNING Q3 ONLY
# ============================================================\n
# ============================= test session starts ==============================
# platform linux -- Python 3.12.12, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# metadata: {'Python': '3.12.12', 'Platform': 'Linux-6.6.105+-x86_64-with-glibc2.35', 'Packages': {'pytest': '8.4.2', 'pluggy': '1.6.0'}, 'Plugins': {'playwright': '0.7.2', 'allure-pytest': '2.15.3', 'base-url': '2.1.0', 'html': '4.1.1', 'metadata': '3.1.1', 'typeguard': '4.4.4', 'langsmith': '0.4.59', 'anyio': '4.12.0'}, 'Base URL': ''}
# rootdir: /content
# configfile: pytest.ini
# plugins: playwright-0.7.2, allure-pytest-2.15.3, base-url-2.1.0, html-4.1.1, metadata-3.1.1, typeguard-4.4.4, langsmith-0.4.59, anyio-4.12.0
# collected 1 item
#
# saucedemo_tests/test_saucedemo.py::TestSauceDemo::test_performance_glitch_user_purchase Added product: Test.allTheThings() T-Shirt (Red) - $15.99
# Product name verified: Test.allTheThings() T-Shirt (Red)
# Total price verified: $15.99
# Order successful: 'Thank you for your order!'
# Q3 Test Passed: Performance glitch user purchase successful
# PASSED
#
# ============================== 1 passed in 26.10s ==============================

# %%
# Cell 11: Generate and Display Allure Report
print("\\n" + "="*60)
print("GENERATING ALLURE REPORT")
print("="*60 + "\\n")

# !allure generate allure-results --clean -o allure-report

# Install a simple HTTP server to view the report
# !pip install -q aiohttp

# Create a simple script to serve the report
serve_script = '''
import os
from aiohttp import web
import asyncio

async def serve_report(request):
    file_path = os.path.join('allure-report', 'index.html')
    with open(file_path, 'r') as f:
        return web.Response(text=f.read(), content_type='text/html')

async def serve_static(request):
    path = request.match_info['path']
    file_path = os.path.join('allure-report', path)

    if os.path.exists(file_path):
        with open(file_path, 'rb') as f:
            content_type = 'text/html'
            if path.endswith('.js'):
                content_type = 'application/javascript'
            elif path.endswith('.css'):
                content_type = 'text/css'
            elif path.endswith('.json'):
                content_type = 'application/json'

            return web.Response(body=f.read(), content_type=content_type)
    return web.Response(status=404)

app = web.Application()
app.router.add_get('/', serve_report)
app.router.add_get('/{path:.*}', serve_static)

web.run_app(app, host='0.0.0.0', port=8080)
'''

with open('serve_report.py', 'w') as f:
    f.write(serve_script)

print("Allure report generated!")
# Out:
# \n============================================================
# GENERATING ALLURE REPORT
# ============================================================\n
# Report successfully generated to allure-report
# Allure report generated!

# %%
# Cell 12: Create ZIP of Reports
print("\\n" + "="*60)
print("CREATING ZIP FILE FOR DOWNLOAD")
print("="*60 + "\\n")

# !zip -r saucedemo_reports.zip allure-report allure-results

from google.colab import files
print("\\nDownloading reports ZIP file...")
files.download('saucedemo_reports.zip')
# Out:
# \n============================================================
# CREATING ZIP FILE FOR DOWNLOAD
# ============================================================\n
#   adding: allure-report/ (stored 0%)
#   adding: allure-report/history/ (stored 0%)
#   adding: allure-report/history/retry-trend.json (stored 0%)
#   adding: allure-report/history/history.json (deflated 62%)
#   adding: allure-report/history/history-trend.json (deflated 18%)
#   adding: allure-report/history/categories-trend.json (stored 0%)
#   adding: allure-report/history/duration-trend.json (stored 0%)
#   adding: allure-report/styles.css (deflated 50%)
#   adding: allure-report/index.html (deflated 54%)
#   adding: allure-report/widgets/ (stored 0%)
#   adding: allure-report/widgets/retry-trend.json (stored 0%)
#   adding: allure-report/widgets/history-trend.json (deflated 18%)
#   adding: allure-report/widgets/categories.json (stored 0%)
#   adding: allure-report/widgets/environment.json (stored 0%)
#   adding: allure-report/widgets/suites.json (deflated 22%)
#   adding: allure-report/widgets/severity.json (deflated 51%)
#   adding: allure-report/widgets/categories-trend.json (stored 0%)
#   adding: allure-report/widgets/duration-trend.json (stored 0%)
#   adding: allure-report/widgets/summary.json (deflated 32%)
#   adding: allure-report/widgets/status-chart.json (deflated 51%)
#   adding: allure-report/widgets/duration.json (deflated 51%)
#   adding: allure-report/widgets/executors.json (stored 0%)
#   adding: allure-report/widgets/behaviors.json (stored 0%)
#   adding: allure-report/widgets/launch.json (stored 0%)
#   adding: allure-report/app.js (deflated 74%)
#   adding: allure-report/data/ (stored 0%)
#   adding: allure-report/data/categories.csv (stored 0%)
#   adding: allure-report/data/behaviors.csv (deflated 29%)
#   adding: allure-report/data/packages.json (deflated 64%)
#   adding: allure-report/data/categories.json (stored 0%)
#   adding: allure-report/data/attachments/ (stored 0%)
#   adding: allure-report/data/attachments/a9187e3eb22d606.txt (deflated 23%)
#   adding: allure-report/data/attachments/5bda3239038c9b11.txt (deflated 29%)
#   adding: allure-report/data/attachments/b104f7964bd57860.png (deflated 23%)
#   adding: allure-report/data/attachments/ff77051c1f9c23db.txt (stored 0%)
#   adding: allure-report/data/attachments/99d62bb3b8dd72d3.png (deflated 21%)
#   adding: allure-report/data/attachments/afd063eee07208e3.txt (deflated 29%)
#   adding: allure-report/data/attachments/d4e545b4ff7b9c5.txt (deflated 23%)
#   adding: allure-report/data/attachments/1ac8353e999e713b.txt (stored 0%)
#   adding: allure-report/data/attachments/fa5777d0fc01f59c.png (deflated 21%)
#   adding: allure-report/data/attachments/60b68d9c65351282.txt (deflated 23%)
#   adding: allure-report/data/attachments/90cbd619867959bd.txt (deflated 23%)
#   adding: allure-report/data/attachments/e81c285b7dd93290.png (deflated 21%)
#   adding: allure-report/data/attachments/8ca59318fdb89475.png (deflated 23%)
#   adding: allure-report/data/attachments/893f1bb83acea299.txt (stored 0%)
#   adding: allure-report/data/attachments/7f003699265eb498.png (deflated 21%)
#   adding: allure-report/data/attachments/93e6a916049181b.txt (stored 0%)
#   adding: allure-report/data/test-cases/ (stored 0%)
#   adding: allure-report/data/test-cases/1c4b3682beae6b76.json (deflated 80%)
#   adding: allure-report/data/test-cases/635d8c0eb2668e32.json (deflated 83%)
#   adding: allure-report/data/test-cases/485eb5501e9b4a4f.json (deflated 80%)
#   adding: allure-report/data/test-cases/c681a5c7f6ce795c.json (deflated 84%)
#   adding: allure-report/data/test-cases/7a76813149015f5d.json (deflated 84%)
#   adding: allure-report/data/test-cases/452bbd0a3eb0a96b.json (deflated 83%)
#   adding: allure-report/data/suites.json (deflated 64%)
#   adding: allure-report/data/timeline.json (deflated 74%)
#   adding: allure-report/data/suites.csv (deflated 60%)
#   adding: allure-report/data/behaviors.json (deflated 65%)
#   adding: allure-report/favicon.ico (deflated 62%)
#   adding: allure-report/plugin/ (stored 0%)
#   adding: allure-report/plugin/screen-diff/ (stored 0%)
#   adding: allure-report/plugin/screen-diff/styles.css (deflated 49%)
#   adding: allure-report/plugin/screen-diff/index.js (deflated 77%)
#   adding: allure-report/plugin/packages/ (stored 0%)
#   adding: allure-report/plugin/packages/index.js (deflated 79%)
#   adding: allure-report/plugin/behaviors/ (stored 0%)
#   adding: allure-report/plugin/behaviors/index.js (deflated 77%)
#   adding: allure-report/export/ (stored 0%)
#   adding: allure-report/export/influxDbData.txt (deflated 72%)
#   adding: allure-report/export/prometheusData.txt (deflated 57%)
#   adding: allure-report/export/mail.html (deflated 24%)
#   adding: allure-results/ (stored 0%)
#   adding: allure-results/68037c18-7807-4b8f-bfc9-b43594d22399-container.json (deflated 50%)
#   adding: allure-results/8b24c7d7-f8a7-4370-8a12-a303ef08cfa7-container.json (deflated 38%)
#   adding: allure-results/c9a13cd9-9a34-45e9-a983-89030d34b6df-attachment.txt (deflated 29%)
#   adding: allure-results/5141d63a-bf62-458a-aa01-898d5d380634-container.json (deflated 51%)
#   adding: allure-results/6aadb8e3-e8e4-4234-bb4c-5aa6875a249a-container.json (deflated 48%)
#   adding: allure-results/d2e1f25a-2f3a-4fe0-92a3-27c7281e2043-container.json (deflated 50%)
#   adding: allure-results/87ea6865-68f6-45ec-bb7c-4707724a278f-container.json (deflated 37%)
#   adding: allure-results/51ec42a1-c1e5-4f33-a0f4-8d9dbf33ee80-container.json (deflated 50%)
#   adding: allure-results/cc5f53b6-8ec3-4f8e-b1dc-0492d1a2aded-container.json (deflated 51%)
#   adding: allure-results/9b8753ae-75bf-4582-b3c2-142b397a5753-container.json (deflated 39%)
#   adding: allure-results/86b1b989-c4ff-4125-b57a-013ea796e69f-container.json (deflated 51%)
#   adding: allure-results/3ebc1035-d759-4f5b-a366-591a517d2e77-attachment.png (deflated 21%)
#   adding: allure-results/763d63a6-b7db-477b-8151-577427a2ec31-container.json (deflated 39%)
#   adding: allure-results/d7a1b97e-addc-420c-bd9a-fc430793be8b-container.json (deflated 50%)
#   adding: allure-results/ae470761-7c9f-4bcb-a18d-f93d1b68581f-container.json (deflated 38%)
#   adding: allure-results/29899354-f538-4dd8-b9e7-7b76f5f3e310-result.json (deflated 69%)
#   adding: allure-results/2a4e686d-5523-44d6-9eb3-9642d9a4ce22-attachment.txt (stored 0%)
#   adding: allure-results/703f3176-afcc-4ad6-98c6-17d3d8d65b5d-attachment.png (deflated 21%)
#   adding: allure-results/51d3e867-fb80-4102-a2f0-4fe34e38c457-attachment.txt (deflated 23%)
#   adding: allure-results/3829b68e-c68f-4692-b77a-3a4d22cbdcbe-attachment.png (deflated 23%)
#   adding: allure-results/6f227168-aeed-4bcb-86c0-a0835624cb81-container.json (deflated 50%)
#   adding: allure-results/fc629f98-e7f9-4ecd-98c6-7da5284aafed-container.json (deflated 38%)
#   adding: allure-results/9f299c37-3c71-4974-ab01-44d3524e62cc-container.json (deflated 38%)
#   adding: allure-results/7a8f9468-7de3-491b-a162-4d886c8263c3-attachment.png (deflated 21%)
#   adding: allure-results/2fd0dd6a-b721-4b22-9b57-e9f4180f67af-container.json (deflated 39%)
#   adding: allure-results/86eff5f3-7b82-46f9-86b5-693d59983f37-container.json (deflated 38%)
#   adding: allure-results/6194077b-aae4-484b-9a5d-1162016cd152-result.json (deflated 62%)
#   adding: allure-results/7d0fc83c-b1e0-4cd9-a49d-a3b82ee4c0ac-container.json (deflated 50%)
#   adding: allure-results/fddb6af6-1690-4e4e-acd4-b7684003fbc9-container.json (deflated 39%)
#   adding: allure-results/c41251e6-5aec-40d6-8ec0-7b4a3c435aa6-result.json (deflated 69%)
#   adding: allure-results/8dfc42a3-1f9f-45ab-8864-d524767008aa-attachment.png (deflated 23%)
#   adding: allure-results/b52b8604-45fd-45dd-82a0-d2b98285d41c-container.json (deflated 51%)
#   adding: allure-results/b3399fcb-00d8-4a78-8ace-1dce8c6648d6-attachment.txt (stored 0%)
#   adding: allure-results/5881552d-5567-4a94-b0ef-2e393e6d1378-attachment.txt (stored 0%)
#   adding: allure-results/909705c5-221a-438c-b040-467c6224ddbf-attachment.txt (deflated 29%)
#   adding: allure-results/0564eb5d-d36d-4976-ad5e-0aa7c463aafb-container.json (deflated 38%)
#   adding: allure-results/fd5d4f5d-ee59-4016-a4ad-6a8c009a7934-attachment.txt (deflated 23%)
#   adding: allure-results/390dec01-b302-4024-be40-01eda133e99a-attachment.txt (deflated 23%)
#   adding: allure-results/f241245d-6bb5-4e03-ab57-6081676c20b5-container.json (deflated 51%)
#   adding: allure-results/ae6a3db7-0c2d-482b-a2f4-d39aea9f38c7-container.json (deflated 38%)
#   adding: allure-results/7a038520-0e11-4764-860b-97b284f187a3-container.json (deflated 50%)
#   adding: allure-results/39210c7e-c789-442a-9e21-79d22a44feb5-attachment.txt (stored 0%)
#   adding: allure-results/873fc1d4-699d-4daf-939b-8d0c6ab43fcf-result.json (deflated 68%)
#   adding: allure-results/2b66c2bb-0bd6-46b0-91bd-0ab3c53f546e-container.json (deflated 50%)
#   adding: allure-results/a246ccca-e266-4a66-b436-8497cc0a68e9-container.json (deflated 51%)
#   adding: allure-results/7c5af4c1-fd3d-4e6d-bf1c-38b6844667b1-container.json (deflated 38%)
#   adding: allure-results/78a8656c-e77d-4c85-9543-b36aa47d3280-result.json (deflated 62%)
#   adding: allure-results/a398ff92-eec4-46a6-a43b-7fa141902b0a-container.json (deflated 38%)
#   adding: allure-results/1195379e-a291-47e3-a1af-8dfa75fe542e-container.json (deflated 50%)
#   adding: allure-results/0af113e3-db81-4a44-8e63-3d426c18b757-container.json (deflated 39%)
#   adding: allure-results/6e81e4de-1ed0-46f6-88a5-d3c9bed832fe-attachment.png (deflated 21%)
#   adding: allure-results/ba83fe2f-e487-44be-80a9-3507e6e3ccd1-attachment.txt (deflated 23%)
#   adding: allure-results/054ef48a-6622-4fe7-9b1a-33bb1ff634f7-result.json (deflated 69%)
#   adding: allure-results/d1957c92-968d-4ed7-a36a-6aa225be835c-container.json (deflated 38%)
# \nDownloading reports ZIP file...

# %%
# Cell 13: Display Test Summary
print("\\n" + "="*60)
print("TEST EXECUTION SUMMARY")
print("="*60)

# !pytest saucedemo_tests/test_saucedemo.py --collect-only

print("\\nAll tests completed!")
print("\\nTest Results:")
print("- Q1: Locked out user error message verification")
print("- Q2: Standard user complete purchase journey")
print("- Q3: Performance glitch user with filtering")
# Out:
# \n============================================================
# TEST EXECUTION SUMMARY
# ============================================================
# ============================= test session starts ==============================
# platform linux -- Python 3.12.12, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# metadata: {'Python': '3.12.12', 'Platform': 'Linux-6.6.105+-x86_64-with-glibc2.35', 'Packages': {'pytest': '8.4.2', 'pluggy': '1.6.0'}, 'Plugins': {'playwright': '0.7.2', 'allure-pytest': '2.15.3', 'base-url': '2.1.0', 'html': '4.1.1', 'metadata': '3.1.1', 'typeguard': '4.4.4', 'langsmith': '0.4.59', 'anyio': '4.12.0'}, 'Base URL': ''}
# rootdir: /content
# configfile: pytest.ini
# plugins: playwright-0.7.2, allure-pytest-2.15.3, base-url-2.1.0, html-4.1.1, metadata-3.1.1, typeguard-4.4.4, langsmith-0.4.59, anyio-4.12.0
# collected 3 items
#
# <Dir content>
#   <Dir saucedemo_tests>
#     <Module test_saucedemo.py>
#       <Class TestSauceDemo>
#         Test suite for SauceDemo website
#         <Function test_locked_out_user>
#           Q1: Try login with locked_out_user and verify the error message
#         <Function test_standard_user_purchase>
#           Q2: Login with standard_user and complete purchase journey
#         <Function test_performance_glitch_user_purchase>
#           Q3: Login with performance_glitch_user and complete purchase with filtering
#
# ========================== 3 tests collected in 0.02s ==========================
# \nAll tests completed!
# \nTest Results:
# - Q1: Locked out user error message verification
# - Q2: Standard user complete purchase journey
# - Q3: Performance glitch user with filtering
